# %%
from typing import List

def make_list_string_lower(list_string: List[str]) -> List[str]:
    return [s.strip().lower() for s in list_string]

# %%
import pandas as pd
from glob import glob
import re

# Get a list of all xlsx files
files = glob('./CPs exp 2a data/*.xlsx')

all_string_values = []
situation_action_pairs = []

print(f"number of files: {len(files)}\n")
# Loop through the list of files and read each file
for file in files:
    dataframe = pd.read_excel(file)
    # Now you can do something with the data
    # print(dataframe.columns)
    assert len(dataframe.situation) == len(dataframe.actions)
    for situation, action in zip(dataframe.situation, dataframe.actions):
        s = make_list_string_lower(re.findall('<p>(.*?)</p>', str(situation)))
        a = make_list_string_lower(re.findall('<p>(.*?)</p>', str(action)))

        situation_action_pairs.append((s, a))

        for s_ in s:
            all_string_values.append(s_)

        for a_ in a:
            all_string_values.append(a_)

        print(f"situation: {s}\naction: {a}\n")
    
print(f"number of unique all_string_values: {len(set(all_string_values))}\n")
# Out:
# number of files: 10
#
# situation: ['top of rock pile', 'large rock']
# action: ['human', 'pick up', 'in', 'large rock', 'top of rock pile', 'robot', 'break', 'in', 'large rock', 'top of rock pile', 'robot', 'break', 'in', 'large rock', 'top of rock pile']
#
# situation: ['top of rock pile', 'large rock']
# action: ['robot', 'break', 'in', 'large rock', 'top of rock pile', 'all']
#
# situation: ['top of rock pile', 'large rock']
# action: ['human', 'pick up', 'in', 'large rock', 'top of rock pile', 'robot', 'break', 'in', 'large rock', 'top of rock pile', 'robot', 'break', 'in', 'large rock', 'top of rock pile']
#
# situation: ['top of rock pile', 'large rock']
# action: ['robot', 'break', 'in', 'large rock', 'top of rock pile', 'all']
#
# situation: ['top of rock pile', 'small rock']
# action: ['human', 'pick up', 'in', 'small rock', 'top of rock pile', 'all', 'drop', 'in', 'small rock', 'side of field', 'all']
#
# situation: ['top of rock pile', 'small rock']
# ...

# %%
len(situation_action_pairs)
# Out:
# 219

# %%
situation_action_pairs[1]
# Out:
# (['top of rock pile', 'large rock'],
#  ['robot', 'break', 'in', 'large rock', 'top of rock pile', 'all'])
