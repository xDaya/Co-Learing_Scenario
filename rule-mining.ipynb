# %% [markdown]
# ## Parse data

# %%
import warnings
from typing import List
import math

import pandas as pd
from glob import glob
import re
from bs4 import BeautifulSoup

warnings.filterwarnings("ignore", category=DeprecationWarning)

# Get a list of all xlsx files
files = sorted(glob("CPs exp 2a data/*.xlsx"))

# all_string_values = []
situations = []
actions = []

print(f"number of files: {len(files)}\n")
# Loop through the list of files and read each file
for file in files:
    print(f"processing `{file}` ...")
    dataframe = pd.read_excel(file)
    dataframe.drop_duplicates(subset="name", keep="last", inplace=True)
    # Now you can do something with the data
    assert len(dataframe.situation) == len(dataframe.actions)
    print(
        f"There are in total of {len(dataframe.situation)} situation-action pairs "
        f"in the file {file}.\n"
    )

    for situation, action in zip(dataframe.situation, dataframe.actions):
        # Parse HTML content
        situation_parsed = []

        if isinstance(situation, float) and math.isnan(situation):
            situation_parsed = None

        else:
            soup = BeautifulSoup(situation, "html.parser")

            # Extract data
            for div in soup.find_all("div", class_="item"):
                # Extract class and text content

                class_name = (
                    div.get("class")[1]
                    if len(div.get("class")) > 1
                    else div.get("class")[0]
                )
                # Process the text content more carefully to add spaces around buttons
                # or special divs
                texts = div.find_all(text=True)
                text_content = " ".join(text.strip() for text in texts).strip().lower()
                situation_parsed.append((class_name, text_content))

        situations.append(situation_parsed)

        soup = BeautifulSoup(action, "html.parser")
        action_parsed = {}

        # Extract boxes
        boxes = soup.find_all("div", class_="box box_action")

        for box in boxes:
            box_id = box.get("id")
            action_parsed[box_id] = []

            items = box.find_all("div", class_="item")
            for item in items:
                class_name = (
                    item.get("class")[1]
                    if len(item.get("class")) > 1
                    else item.get("class")[0]
                )
                # Process the text content more carefully to add spaces around buttons
                # or special divs
                texts = item.find_all(text=True)
                text_content = " ".join(text.strip() for text in texts).strip().lower()
                action_parsed[box_id].append((class_name, text_content))

        actions.append(action_parsed)
        assert len(situations) == len(actions)

situation_action_pairs = list(zip(situations, actions))

print(
    f"In total of {len(situation_action_pairs)} situation-action pairs have "
    f"been processed.\n"
)

# Create a new list with elements that don't have None as the situation
situation_action_pairs = [
    (situation, action)
    for situation, action in situation_action_pairs
    if situation is not None
]
print(
    f"After removing None, now there is {len(situation_action_pairs)} "
    f"situation-action pairs.\n"
)

for idx, (situation, actions_dict) in enumerate(situation_action_pairs.copy()):
    actions_list = []
    for action in actions_dict.values():
        if action:
            actions_list.append(action)

    if actions_list:
        situation_action_pairs[idx] = situation, actions_list

print(
    f"After removing empty actions, now there is {len(situation_action_pairs)} "
    f"situation-action pairs.\n"
)

# %% [markdown]
# ## Get the stats of situations and actions

# %%
from collections import Counter

unique_ = dict(
    Counter([s for situation, actions in situation_action_pairs for s in situation])
)
unique_ = dict(sorted(unique_.items(), key=lambda item: item[1], reverse=True))
unique_
# Out:
# {('objects', 'large rock'): 140,
#  ('objects', 'small rock'): 102,
#  ('locations', 'top of rock pile'): 79,
#  ('locations', 'left side of rock pile'): 59,
#  ('agents', 'victim'): 33,
#  ('agents', 'human'): 31,
#  ('locations', 'bottom of rock pile'): 29,
#  ('agents', 'robot'): 29,
#  ('locations', 'on top of actor'): 28,
#  ('locations', 'on top of object'): 13,
#  ('counters', 'all'): 8,
#  ('counters', 'one'): 7,
#  ('locations', 'left side of field'): 3,
#  ('locations', 'above rock pile'): 3,
#  ('actions', 'move to object'): 3,
#  ('locations', 'right side of rock pile'): 2,
#  ('locations', 'right side of field'): 2,
#  ('objects', 'brown rock'): 1,
#  ('actions', 'break object in location'): 1,
#  ('actions', 'pick up object in location'): 1,
#  ('actions', 'move back and forth in location'): 1}

# %%
unique_ = dict(
    Counter(
        [
            a
            for situation, actions in situation_action_pairs
            for action in actions
            for a in action
        ]
    )
)
unique_ = dict(sorted(unique_.items(), key=lambda item: item[1], reverse=True))
unique_
# Out:
# {('agents', 'robot'): 226,
#  ('agents', 'human'): 208,
#  ('objects', 'large rock'): 181,
#  ('actions', 'pick up object in location'): 181,
#  ('objects', 'small rock'): 178,
#  ('locations', 'top of rock pile'): 90,
#  ('locations', 'left side of rock pile'): 88,
#  ('actions', 'drop object in location'): 86,
#  ('actions', 'break object in location'): 68,
#  ('locations', 'on top of actor'): 47,
#  ('agents', 'victim'): 46,
#  ('locations', 'left side of field'): 45,
#  ('locations', 'bottom of rock pile'): 35,
#  ('counters', 'all'): 35,
#  ('locations', 'right side of field'): 32,
#  ('actions', 'move to object'): 31,
#  ('actions', 'stand still in location'): 30,
#  ('actions', 'move back and forth in location'): 20,
#  ('counters', 'one'): 16,
#  ('actions', 'move to location'): 16,
#  ('actions', 'move to actor'): 13,
#  ('locations', 'right side of rock pile'): 12,
#  ('locations', 'on top of object'): 12,
#  ('locations', 'above rock pile'): 10,
#  ('counters', 'zero'): 2,
#  ('locations', 'on top of location'): 1}

# %% [markdown]
# ## Print raw

# %%
for idx, (situation, actions) in enumerate(situation_action_pairs):
    print(f"case {idx}")
    print(f"situation: {situation}")
    print(f"actions: {actions}")
    print("-" * 88)
    print()
# Out:
# case 0
# situation: [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'bottom of rock pile'), ('objects', 'large rock')]
# actions: [[('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'right side of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'bottom of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 1
# situation: [('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'move to object'), ('counters', 'zero'), ('objects', 'small rock')]]
# ----------------------------------------------------------------------------------------
#
# case 2
# situation: [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'small rock')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'right side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 3
# situation: [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'left side of rock pile'), ('objects', 'large rock'), ('locations', 'right side of rock pile'), ('objects', 'large rock'), ('agents', 'victim')]
# actions: [[('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'right side of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'right side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 4
# situation: [('locations', 'bottom of rock pile'), ('objects', 'large rock')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'bottom of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('locations', 'bottom of rock pile'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'small rock')]]
# ----------------------------------------------------------------------------------------
#
# case 5
# situation: [('locations', 'left side of rock pile'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim'), ('objects', 'small rock')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 6
# situation: [('locations', 'on top of object'), ('objects', 'small rock'), ('objects', 'large rock')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock')]]
# ----------------------------------------------------------------------------------------
#
# case 7
# situation: [('objects', 'small rock'), ('locations', 'top of rock pile'), ('locations', 'top of rock pile'), ('objects', 'large rock')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 8
# situation: [('locations', 'top of rock pile'), ('objects', 'small rock'), ('locations', 'on top of object'), ('objects', 'small rock'), ('objects', 'large rock')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')]]
# ----------------------------------------------------------------------------------------
#
# case 9
# situation: [('locations', 'top of rock pile'), ('objects', 'large rock'), ('objects', 'small rock'), ('locations', 'bottom of rock pile'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('objects', 'small rock')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 10
# situation: [('locations', 'left side of rock pile'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')]]
# ----------------------------------------------------------------------------------------
#
# case 11
# situation: [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim'), ('objects', 'large rock')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 12
# situation: [('locations', 'left side of rock pile'), ('objects', 'large rock'), ('locations', 'left side of field'), ('objects', 'small rock')]
# actions: [[('locations', 'left side of rock pile'), ('actions', 'pick up object in location'), ('agents', 'robot'), ('objects', 'large rock')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 13
# situation: [('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')]]
# ----------------------------------------------------------------------------------------
#
# case 14
# situation: [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'small rock')]
# actions: [[('agents', 'robot'), ('objects', 'large rock'), ('actions', 'break object in location')], [('agents', 'human'), ('objects', 'small rock'), ('actions', 'pick up object in location')], [('agents', 'robot'), ('objects', 'large rock'), ('actions', 'break object in location')], [('agents', 'robot'), ('agents', 'human'), ('objects', 'small rock'), ('actions', 'pick up object in location')]]
# ----------------------------------------------------------------------------------------
#
# case 15
# situation: [('objects', 'small rock'), ('locations', 'top of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('counters', 'zero')]]
# ----------------------------------------------------------------------------------------
#
# case 16
# situation: [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'small rock')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')]]
# ----------------------------------------------------------------------------------------
#
# case 17
# situation: [('locations', 'left side of rock pile'), ('objects', 'large rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')]]
# ----------------------------------------------------------------------------------------
#
# case 18
# situation: [('locations', 'bottom of rock pile'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 19
# situation: [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('locations', 'left side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 20
# situation: [('locations', 'left side of rock pile'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('objects', 'small rock')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('locations', 'on top of actor')]]
# ----------------------------------------------------------------------------------------
#
# case 21
# situation: [('locations', 'left side of rock pile'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('objects', 'large rock')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('counters', 'one')]]
# ----------------------------------------------------------------------------------------
#
# case 22
# situation: [('locations', 'top of rock pile'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('objects', 'large rock')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('actions', 'pick up object in location')]]
# ----------------------------------------------------------------------------------------
#
# case 23
# situation: [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'small rock')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 24
# situation: [('locations', 'top of rock pile'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('objects', 'large rock')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 25
# situation: [('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 26
# situation: [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'bottom of rock pile'), ('objects', 'small rock'), ('locations', 'bottom of rock pile'), ('objects', 'large rock')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('locations', 'bottom of rock pile'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('locations', 'bottom of rock pile'), ('objects', 'large rock')]]
# ----------------------------------------------------------------------------------------
#
# case 27
# situation: [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 28
# situation: [('objects', 'large rock'), ('objects', 'small rock'), ('locations', 'top of rock pile')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location')], [('agents', 'robot'), ('actions', 'pick up object in location')]]
# ----------------------------------------------------------------------------------------
#
# case 29
# situation: [('objects', 'small rock'), ('locations', 'top of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location')]]
# ----------------------------------------------------------------------------------------
#
# case 30
# situation: [('counters', 'all'), ('objects', 'large rock'), ('objects', 'small rock'), ('locations', 'top of rock pile')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 31
# situation: [('counters', 'all'), ('objects', 'large rock')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 32
# situation: [('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'left side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 33
# situation: [('objects', 'large rock'), ('locations', 'on top of object'), ('objects', 'large rock')]
# actions: [[('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'right side of field')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'on top of object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'right side of field')], [('agents', 'robot'), ('actions', 'stand still in location'), ('locations', 'right side of field')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock')]]
# ----------------------------------------------------------------------------------------
#
# case 34
# situation: [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')]]
# ----------------------------------------------------------------------------------------
#
# case 35
# situation: [('counters', 'one'), ('objects', 'large rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 36
# situation: [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'top of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 37
# situation: [('objects', 'large rock'), ('locations', 'top of rock pile')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'above rock pile')], [('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'right side of field')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 38
# situation: [('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'small rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 39
# situation: [('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'above rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 40
# situation: [('counters', 'one'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 41
# situation: [('objects', 'large rock'), ('locations', 'top of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('agents', 'human'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 42
# situation: [('locations', 'top of rock pile'), ('objects', 'small rock'), ('agents', 'human')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('counters', 'all')], [('agents', 'human'), ('actions', 'drop object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'left side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 43
# situation: [('objects', 'large rock'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('agents', 'human'), ('agents', 'robot')]
# actions: [[('agents', 'human'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('counters', 'all')], [('agents', 'robot'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('counters', 'all')], [('actions', 'drop object in location'), ('agents', 'human'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'drop object in location'), ('locations', 'left side of field'), ('objects', 'large rock')]]
# ----------------------------------------------------------------------------------------
#
# case 44
# situation: [('objects', 'large rock'), ('locations', 'left side of rock pile'), ('agents', 'human'), ('agents', 'robot')]
# actions: [[('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'left side of rock pile'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('counters', 'all'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('counters', 'all'), ('locations', 'left side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 45
# situation: [('objects', 'small rock'), ('counters', 'all'), ('locations', 'left side of rock pile'), ('locations', 'bottom of rock pile'), ('agents', 'human'), ('agents', 'robot')]
# actions: [[('agents', 'human'), ('objects', 'small rock'), ('actions', 'pick up object in location'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('objects', 'small rock'), ('actions', 'pick up object in location')], [('agents', 'human'), ('objects', 'small rock'), ('actions', 'drop object in location'), ('locations', 'left side of field')], [('agents', 'robot'), ('objects', 'small rock'), ('actions', 'move back and forth in location')]]
# ----------------------------------------------------------------------------------------
#
# case 46
# situation: [('objects', 'large rock'), ('objects', 'brown rock'), ('locations', 'left side of rock pile'), ('locations', 'top of rock pile'), ('agents', 'robot')]
# actions: [[('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'right side of field')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')], [('agents', 'human'), ('objects', 'small rock'), ('actions', 'pick up object in location'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('objects', 'small rock'), ('actions', 'drop object in location'), ('locations', 'left side of field')], [('agents', 'human'), ('actions', 'move back and forth in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 47
# situation: [('locations', 'top of rock pile'), ('locations', 'left side of rock pile'), ('objects', 'large rock'), ('agents', 'robot'), ('agents', 'human')]
# actions: [[('agents', 'human'), ('actions', 'move to object'), ('locations', 'above rock pile'), ('locations', 'on top of object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 48
# situation: [('locations', 'left side of rock pile'), ('objects', 'small rock'), ('objects', 'large rock'), ('agents', 'human'), ('agents', 'robot')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'human')], [('agents', 'human'), ('actions', 'move to location'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'human')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'human'), ('actions', 'move to location'), ('locations', 'top of rock pile'), ('agents', 'robot')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('objects', 'small rock'), ('actions', 'drop object in location'), ('locations', 'left side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 49
# situation: [('objects', 'small rock'), ('objects', 'large rock'), ('agents', 'robot'), ('agents', 'human'), ('agents', 'victim'), ('locations', 'top of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'move to location'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('objects', 'large rock'), ('actions', 'move to actor'), ('agents', 'human')]]
# ----------------------------------------------------------------------------------------
#
# case 50
# situation: [('objects', 'large rock'), ('objects', 'small rock'), ('agents', 'human'), ('agents', 'robot'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'move to location'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'move to location'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'stand still in location'), ('objects', 'large rock'), ('locations', 'on top of object'), ('locations', 'left side of rock pile')], [('objects', 'large rock'), ('agents', 'robot'), ('actions', 'break object in location'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'human')], [('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'left side of rock pile'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 51
# situation: [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('agents', 'robot'), ('agents', 'human')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('counters', 'all'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('agents', 'human'), ('actions', 'drop object in location'), ('counters', 'all'), ('objects', 'large rock'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('objects', 'small rock'), ('counters', 'all'), ('locations', 'top of rock pile'), ('actions', 'pick up object in location')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('counters', 'all'), ('locations', 'right side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 52
# situation: [('objects', 'large rock'), ('agents', 'human'), ('locations', 'bottom of rock pile'), ('agents', 'victim')]
# actions: [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'on top of object'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'human')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 53
# situation: [('objects', 'small rock'), ('locations', 'left side of rock pile'), ('agents', 'human'), ('agents', 'robot')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 54
# situation: [('objects', 'large rock'), ('agents', 'human'), ('agents', 'robot'), ('locations', 'bottom of rock pile'), ('locations', 'left side of rock pile')]
# actions: [[('objects', 'large rock'), ('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'on top of object'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'human')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 55
# situation: [('locations', 'top of rock pile'), ('objects', 'large rock')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'one'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'move to object'), ('counters', 'all'), ('objects', 'small rock')]]
# ----------------------------------------------------------------------------------------
#
# case 56
# situation: [('objects', 'small rock'), ('locations', 'top of rock pile')]
# actions: [[('agents', 'human'), ('counters', 'one'), ('objects', 'small rock'), ('actions', 'pick up object in location'), ('locations', 'left side of field')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 57
# situation: [('objects', 'large rock'), ('objects', 'small rock'), ('agents', 'robot'), ('agents', 'human'), ('locations', 'above rock pile')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')], [('agents', 'human'), ('agents', 'robot'), ('actions', 'move to object'), ('counters', 'all'), ('locations', 'left side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 58
# situation: [('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'left side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 59
# situation: [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'right side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 60
# situation: [('objects', 'large rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('actions', 'move to object'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'small rock'), ('actions', 'drop object in location'), ('locations', 'left side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 61
# situation: [('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('locations', 'above rock pile'), ('objects', 'large rock')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'above rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'right side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 62
# situation: [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'on top of object'), ('agents', 'victim')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'on top of object'), ('agents', 'victim')], [('agents', 'robot'), ('objects', 'large rock'), ('actions', 'pick up object in location')], [('agents', 'robot'), ('actions', 'drop object in location'), ('locations', 'on top of object'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 63
# situation: [('locations', 'left side of rock pile'), ('objects', 'large rock'), ('objects', 'small rock'), ('agents', 'robot'), ('agents', 'human'), ('actions', 'break object in location')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')], [('agents', 'human'), ('actions', 'drop object in location'), ('locations', 'left side of field'), ('objects', 'small rock')]]
# ----------------------------------------------------------------------------------------
#
# case 64
# situation: [('counters', 'all'), ('objects', 'small rock'), ('agents', 'human'), ('agents', 'robot'), ('locations', 'left side of field'), ('locations', 'right side of field')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('counters', 'all'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'right side of field')], [('agents', 'robot'), ('actions', 'drop object in location'), ('counters', 'one'), ('objects', 'small rock'), ('locations', 'left side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 65
# situation: [('objects', 'large rock'), ('locations', 'bottom of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'bottom of rock pile')], [('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')]]
# ----------------------------------------------------------------------------------------
#
# case 66
# situation: [('objects', 'large rock'), ('objects', 'small rock'), ('agents', 'robot'), ('agents', 'human'), ('locations', 'left side of field'), ('locations', 'right side of field')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')], [('actions', 'drop object in location'), ('agents', 'robot'), ('locations', 'left side of field')], [('agents', 'human'), ('objects', 'small rock'), ('actions', 'pick up object in location')], [('locations', 'left side of field'), ('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'drop object in location'), ('locations', 'right side of field'), ('objects', 'large rock')]]
# ----------------------------------------------------------------------------------------
#
# case 67
# situation: [('objects', 'large rock'), ('locations', 'bottom of rock pile'), ('agents', 'robot'), ('agents', 'human')]
# actions: [[('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 68
# situation: [('locations', 'top of rock pile'), ('objects', 'large rock')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 69
# situation: [('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('actions', 'drop object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 70
# situation: [('locations', 'top of rock pile'), ('objects', 'small rock')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 71
# situation: [('locations', 'top of rock pile'), ('objects', 'small rock')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 72
# situation: [('agents', 'human'), ('objects', 'small rock')]
# actions: [[('actions', 'move to location'), ('locations', 'left side of rock pile')], [('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 73
# situation: [('locations', 'top of rock pile'), ('objects', 'large rock')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 74
# situation: [('agents', 'robot'), ('objects', 'large rock')]
# actions: [[('actions', 'move to location'), ('locations', 'left side of rock pile')], [('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 75
# situation: [('agents', 'robot'), ('objects', 'small rock')]
# actions: [[('actions', 'move to location'), ('locations', 'left side of rock pile')], [('actions', 'drop object in location'), ('counters', 'all'), ('locations', 'left side of rock pile'), ('objects', 'small rock')]]
# ----------------------------------------------------------------------------------------
#
# case 76
# situation: [('locations', 'bottom of rock pile'), ('objects', 'small rock')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 77
# situation: [('locations', 'bottom of rock pile'), ('objects', 'large rock')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'bottom of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 78
# situation: [('locations', 'bottom of rock pile'), ('objects', 'small rock')]
# ...
# ----------------------------------------------------------------------------------------
#
# case 139
# situation: [('objects', 'small rock'), ('locations', 'right side of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('locations', 'right side of rock pile'), ('objects', 'small rock')], [('agents', 'human'), ('actions', 'move to location'), ('locations', 'left side of field')], [('agents', 'human'), ('actions', 'move to location'), ('locations', 'right side of field')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'right side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 140
# situation: [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field'), ('locations', 'above rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 141
# situation: [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('objects', 'large rock'), ('locations', 'left side of rock pile'), ('actions', 'pick up object in location')], [('agents', 'robot'), ('actions', 'drop object in location'), ('locations', 'right side of field'), ('locations', 'above rock pile'), ('objects', 'large rock')]]
# ----------------------------------------------------------------------------------------
#
# case 142
# situation: [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('objects', 'large rock'), ('locations', 'left side of rock pile'), ('actions', 'pick up object in location')]]
# ----------------------------------------------------------------------------------------
#
# case 143
# situation: [('objects', 'large rock'), ('locations', 'top of rock pile'), ('locations', 'on top of object'), ('objects', 'large rock')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'one'), ('objects', 'small rock'), ('locations', 'top of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 144
# situation: [('objects', 'large rock'), ('locations', 'on top of object'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim'), ('objects', 'small rock'), ('locations', 'on top of object'), ('objects', 'large rock')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'stand still in location'), ('locations', 'right side of field')], [('agents', 'victim'), ('actions', 'stand still in location'), ('locations', 'bottom of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 145
# situation: [('counters', 'all'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'on top of actor'), ('agents', 'human')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'stand still in location'), ('locations', 'right side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 146
# situation: [('counters', 'one'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 147
# situation: [('counters', 'all'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('locations', 'top of rock pile'), ('locations', 'bottom of rock pile')], [('objects', 'small rock'), ('actions', 'drop object in location'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 148
# situation: [('counters', 'one'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 149
# situation: [('objects', 'large rock'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('locations', 'on top of object'), ('objects', 'large rock')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 150
# situation: [('objects', 'small rock'), ('locations', 'on top of object'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'right side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 151
# situation: [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 152
# situation: [('objects', 'small rock'), ('locations', 'on top of object'), ('agents', 'victim'), ('locations', 'top of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'left side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 153
# situation: [('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('objects', 'small rock'), ('actions', 'drop object in location'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 154
# situation: [('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 155
# situation: [('agents', 'human'), ('actions', 'move back and forth in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'above rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 156
# situation: [('counters', 'all'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 157
# situation: [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'on top of object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock')]]
# ----------------------------------------------------------------------------------------
#
# case 158
# situation: [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 159
# situation: [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'on top of object'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')]]
# ----------------------------------------------------------------------------------------
#
# case 160
# situation: [('objects', 'small rock'), ('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'on top of actor'), ('agents', 'human')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 161
# situation: [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'right side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 162
# situation: [('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
# ----------------------------------------------------------------------------------------
#
# case 163
# situation: [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('locations', 'on top of object'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'left side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 164
# situation: [('objects', 'small rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# actions: [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')]]
# ----------------------------------------------------------------------------------------
#
# case 165
# situation: [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# actions: [[('agents', 'human'), ('locations', 'on top of object'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')]]
# ----------------------------------------------------------------------------------------

# %% [markdown]
# ## Print cleaned

# %%
def remove_words(s: str) -> str:
    s = s.replace("move to object", "moveTo")
    s = s.replace("move to location", "moveTo")
    s = s.replace("move to actor", "moveTo")
    s = s.replace("in location", "")
    s = s.replace("to location", "")
    s = s.replace("on top of location", "topOf")
    s = s.replace("on top of object", "topOf")
    s = s.replace("break object ", "break")
    s = s.replace("robot", "Robot")
    s = s.replace("human", "Human")
    s = s.replace("victim", "Victim")
    s = s.replace("rock pile", "RockPile")
    s = s.replace("field", "Field")
    s = s.replace("large rock", "LargeRock")
    s = s.replace("small rock", "SmallRock")
    s = s.replace("brown rock", "BrownRock")
    s = s.replace("on top of actor", "topOf")
    s = s.replace("top of", "topOf")
    s = s.replace("above", "above,")
    s = s.replace("bottom of", "bottomOf,")
    s = s.replace("right side of", "rightSideOf,")
    s = s.replace("left side of", "leftSideOf,")
    s = s.replace("pick up object ", "pickUp")
    s = s.replace("all, ", "")
    s = s.replace("one, ", "")
    s = s.replace("zero, ", "")
    s = s.replace("move back and forth", "hasState, MoveBackAndForth")
    s = s.replace("drop object ", "drop")
    s = s.replace("stand still ", "hasState, standStill")


    return s

for idx, (situation, actions) in enumerate(situation_action_pairs):
    print(f"case {idx}")

    situation_str = ", ".join([s[1].strip() for s in situation])
    actions_str = ", ".join([a_[1].strip() for a in actions for a_ in a])

    situation_str = remove_words(situation_str)
    actions_str = remove_words(actions_str)

    print(f"situation: {situation_str}")
    print(f"actions: {actions_str}")
    print("-" * 88)
    print()
# Out:
# case 0
# situation: topOf RockPile, LargeRock, bottomOf, RockPile, LargeRock
# actions: Robot, moveTo, LargeRock, Human, moveTo, LargeRock, Robot, break, LargeRock, rightSideOf, RockPile, Robot, break, LargeRock, bottomOf, RockPile, Human, pickUp, SmallRock, topOf RockPile, Robot, pickUp, SmallRock, topOf RockPile
# ----------------------------------------------------------------------------------------
#
# case 1
# situation: SmallRock, topOf RockPile
# actions: Human, hasState, MoveBackAndForth , topOf RockPile, Human, pickUp, SmallRock, topOf RockPile, Robot, moveTo, SmallRock
# ----------------------------------------------------------------------------------------
#
# case 2
# situation: topOf RockPile, LargeRock, topOf RockPile, SmallRock
# actions: Robot, pickUp, SmallRock, topOf RockPile, Human, pickUp, SmallRock, topOf RockPile, Robot, pickUp, LargeRock, leftSideOf, RockPile, Robot, pickUp, LargeRock, rightSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 3
# situation: topOf RockPile, LargeRock, leftSideOf, RockPile, LargeRock, rightSideOf, RockPile, LargeRock, Victim
# actions: Robot, moveTo, LargeRock, Human, moveTo, LargeRock, Robot, break, LargeRock, rightSideOf, RockPile, Human, pickUp, SmallRock, rightSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 4
# situation: bottomOf, RockPile, LargeRock
# actions: Robot, break, LargeRock, bottomOf, RockPile, Human, pickUp, bottomOf, RockPile, SmallRock, Robot, moveTo, SmallRock
# ----------------------------------------------------------------------------------------
#
# case 5
# situation: leftSideOf, RockPile, LargeRock, topOf, Victim, SmallRock
# actions: Robot, break, LargeRock, Human, pickUp, SmallRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 6
# situation: topOf, SmallRock, LargeRock
# actions: Human, pickUp, SmallRock, bottomOf, RockPile, Robot, break, LargeRock
# ----------------------------------------------------------------------------------------
#
# case 7
# situation: SmallRock, topOf RockPile, topOf RockPile, LargeRock
# actions: Human, pickUp, SmallRock, topOf RockPile, Human, drop, SmallRock, topOf, Victim, Robot, pickUp, LargeRock, Robot, moveTo, Victim
# ----------------------------------------------------------------------------------------
#
# case 8
# situation: topOf RockPile, SmallRock, topOf, SmallRock, LargeRock
# actions: Robot, break, LargeRock, Human, pickUp, SmallRock
# ----------------------------------------------------------------------------------------
#
# case 9
# situation: topOf RockPile, LargeRock, SmallRock, bottomOf, RockPile, SmallRock, topOf, SmallRock
# actions: Robot, pickUp, LargeRock, topOf RockPile, Robot, pickUp, SmallRock, topOf RockPile, Human, pickUp, SmallRock, leftSideOf, Field, Robot, pickUp, SmallRock, topOf, Victim, Human, pickUp, SmallRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 10
# situation: leftSideOf, RockPile, LargeRock, topOf, Victim
# actions: Human, moveTo, LargeRock, Robot, moveTo, LargeRock, Robot, pickUp, LargeRock
# ----------------------------------------------------------------------------------------
#
# case 11
# situation: topOf RockPile, LargeRock, topOf, Victim, SmallRock, topOf, Victim, LargeRock
# actions: Robot, pickUp, LargeRock, topOf RockPile, Human, pickUp, SmallRock, topOf, Victim, Robot, pickUp, LargeRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 12
# situation: leftSideOf, RockPile, LargeRock, leftSideOf, Field, SmallRock
# actions: leftSideOf, RockPile, pickUp, Robot, LargeRock, Human, pickUp, SmallRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 13
# situation: LargeRock, topOf, Victim
# actions: Human, moveTo, LargeRock, Robot, moveTo, LargeRock, Robot, pickUp, LargeRock
# ----------------------------------------------------------------------------------------
#
# case 14
# situation: topOf RockPile, LargeRock, topOf RockPile, SmallRock
# actions: Robot, LargeRock, break, Human, SmallRock, pickUp, Robot, LargeRock, break, Robot, Human, SmallRock, pickUp
# ----------------------------------------------------------------------------------------
#
# case 15
# situation: SmallRock, topOf RockPile
# actions: Human, pickUp, SmallRock, Human, drop, SmallRock, Robot, pickUp, zero
# ----------------------------------------------------------------------------------------
#
# case 16
# situation: topOf RockPile, LargeRock, topOf RockPile, SmallRock
# actions: Human, pickUp, SmallRock, Robot, pickUp, LargeRock
# ----------------------------------------------------------------------------------------
#
# case 17
# situation: leftSideOf, RockPile, LargeRock, leftSideOf, RockPile, SmallRock
# actions: Robot, break, LargeRock, Human, pickUp, SmallRock
# ----------------------------------------------------------------------------------------
#
# case 18
# situation: bottomOf, RockPile, SmallRock, topOf, Victim
# actions: Robot, pickUp, SmallRock, Human, pickUp, SmallRock, bottomOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 19
# situation: topOf RockPile, LargeRock, leftSideOf, RockPile, SmallRock
# actions: Human, pickUp, SmallRock, leftSideOf, RockPile, Robot, pickUp, LargeRock, topOf RockPile, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 20
# situation: leftSideOf, RockPile, LargeRock, topOf, SmallRock
# actions: Robot, break, LargeRock, topOf RockPile, Human, pickUp, topOf
# ----------------------------------------------------------------------------------------
#
# case 21
# situation: leftSideOf, RockPile, SmallRock, topOf RockPile, LargeRock
# actions: Human, pickUp, SmallRock, leftSideOf, RockPile, Robot, break, LargeRock, topOf RockPile, one
# ----------------------------------------------------------------------------------------
#
# case 22
# situation: topOf RockPile, SmallRock, topOf RockPile, LargeRock
# actions: Human, pickUp, SmallRock, Human, drop, SmallRock, topOf, Victim, Robot, LargeRock, topOf RockPile, pickUp
# ----------------------------------------------------------------------------------------
#
# case 23
# situation: topOf RockPile, LargeRock, topOf RockPile, SmallRock
# actions: Robot, break, LargeRock, topOf RockPile, Human, pickUp, SmallRock, topOf RockPile, Robot, break, LargeRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 24
# situation: topOf RockPile, SmallRock, topOf RockPile, LargeRock
# actions: Robot, pickUp, LargeRock, topOf RockPile, Robot, pickUp, SmallRock, topOf RockPile, topOf, Victim, Human, pickUp, SmallRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 25
# situation: LargeRock, topOf, Victim
# actions: Robot, pickUp, LargeRock, topOf, Victim, Human, hasState, standStill, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 26
# situation: topOf RockPile, LargeRock, bottomOf, RockPile, SmallRock, bottomOf, RockPile, LargeRock
# actions: Robot, pickUp, LargeRock, topOf RockPile, Human, pickUp, bottomOf, RockPile, SmallRock, Robot, pickUp, bottomOf, RockPile, LargeRock
# ----------------------------------------------------------------------------------------
#
# case 27
# situation: LargeRock, leftSideOf, RockPile
# actions: Human, hasState, standStill, leftSideOf, RockPile, Robot, pickUp, LargeRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 28
# situation: LargeRock, SmallRock, topOf RockPile
# actions: Robot, break, Robot, pickUp
# ----------------------------------------------------------------------------------------
#
# case 29
# situation: SmallRock, topOf RockPile
# actions: Human, pickUp
# ----------------------------------------------------------------------------------------
#
# case 30
# situation: LargeRock, SmallRock, topOf RockPile
# actions: Robot, pickUp, LargeRock, topOf RockPile, Human, pickUp, SmallRock, topOf RockPile
# ----------------------------------------------------------------------------------------
#
# case 31
# situation: LargeRock
# actions: Robot, break, LargeRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 32
# situation: SmallRock, bottomOf, RockPile
# actions: Human, pickUp, SmallRock, bottomOf, RockPile, Robot, hasState, MoveBackAndForth , leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 33
# situation: LargeRock, topOf, LargeRock
# actions: Human, hasState, MoveBackAndForth , rightSideOf, Field, Robot, pickUp, LargeRock, topOf, LargeRock, Robot, hasState, MoveBackAndForth , rightSideOf, Field, Robot, hasState, standStill, rightSideOf, Field, Robot, drop, LargeRock
# ----------------------------------------------------------------------------------------
#
# case 34
# situation: LargeRock, leftSideOf, RockPile
# actions: Robot, break, LargeRock, leftSideOf, RockPile, Human, pickUp, SmallRock
# ----------------------------------------------------------------------------------------
#
# case 35
# situation: LargeRock, leftSideOf, RockPile, SmallRock, leftSideOf, RockPile
# actions: Human, pickUp, SmallRock, leftSideOf, RockPile, Robot, break, LargeRock, leftSideOf, RockPile, Human, pickUp, SmallRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 36
# situation: SmallRock, LargeRock, topOf RockPile
# actions: Human, pickUp, SmallRock, topOf RockPile, Human, drop, SmallRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 37
# situation: LargeRock, topOf RockPile
# actions: Robot, break, LargeRock, topOf RockPile, Human, pickUp, SmallRock, above, RockPile, Robot, hasState, MoveBackAndForth , rightSideOf, Field, Robot, break, SmallRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 38
# situation: LargeRock, topOf RockPile, SmallRock, leftSideOf, RockPile, SmallRock, bottomOf, RockPile
# actions: Robot, pickUp, LargeRock, topOf RockPile, Robot, pickUp, SmallRock, topOf RockPile, Human, pickUp, SmallRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 39
# situation: LargeRock, topOf RockPile, SmallRock, bottomOf, RockPile
# actions: Human, pickUp, SmallRock, bottomOf, RockPile, Robot, pickUp, LargeRock, above, RockPile
# ----------------------------------------------------------------------------------------
#
# case 40
# situation: LargeRock, leftSideOf, RockPile
# actions: Robot, pickUp, LargeRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 41
# situation: LargeRock, topOf RockPile
# actions: Human, moveTo, LargeRock, topOf RockPile, Robot, moveTo, LargeRock, topOf RockPile, Robot, Human, break, LargeRock, topOf RockPile, Robot, break, LargeRock, topOf RockPile
# ----------------------------------------------------------------------------------------
#
# case 42
# situation: topOf RockPile, SmallRock, Human
# actions: Human, pickUp, SmallRock, topOf RockPile, Human, drop, SmallRock, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 43
# situation: LargeRock, SmallRock, topOf RockPile, Human, Robot
# actions: Human, SmallRock, topOf RockPile, Robot, LargeRock, topOf RockPile, drop, Human, SmallRock, leftSideOf, Field, Robot, drop, leftSideOf, Field, LargeRock
# ----------------------------------------------------------------------------------------
#
# case 44
# situation: LargeRock, leftSideOf, RockPile, Human, Robot
# actions: Human, hasState, MoveBackAndForth , leftSideOf, RockPile, LargeRock, Robot, moveTo, LargeRock, leftSideOf, RockPile, Robot, break, LargeRock, leftSideOf, RockPile, Human, Robot, pickUp, SmallRock, leftSideOf, RockPile, Human, Robot, drop, SmallRock, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 45
# situation: SmallRock, leftSideOf, RockPile, bottomOf, RockPile, Human, Robot
# actions: Human, SmallRock, pickUp, leftSideOf, RockPile, Robot, SmallRock, pickUp, Human, SmallRock, drop, leftSideOf, Field, Robot, SmallRock, hasState, MoveBackAndForth
# ----------------------------------------------------------------------------------------
#
# case 46
# situation: LargeRock, BrownRock, leftSideOf, RockPile, topOf RockPile, Robot
# actions: Human, hasState, MoveBackAndForth , rightSideOf, Field, Robot, drop, LargeRock, rightSideOf, Field, Human, SmallRock, pickUp, leftSideOf, RockPile, Human, SmallRock, drop, leftSideOf, Field, Human, hasState, MoveBackAndForth , LargeRock, leftSideOf, RockPile, Robot, pickUp, LargeRock, leftSideOf, RockPile, Robot, drop, LargeRock, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 47
# situation: topOf RockPile, leftSideOf, RockPile, LargeRock, Robot, Human
# actions: Human, moveTo, above, RockPile, topOf, LargeRock, Robot, moveTo, LargeRock, topOf RockPile, Robot, break, LargeRock, topOf RockPile, Human, pickUp, SmallRock, topOf, Victim, Human, drop, SmallRock, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 48
# situation: leftSideOf, RockPile, SmallRock, LargeRock, Human, Robot
# actions: Human, pickUp, SmallRock, leftSideOf, RockPile, Human, drop, SmallRock, leftSideOf, Field, Robot, moveTo, Human, Human, moveTo, bottomOf, RockPile, Robot, break, LargeRock, topOf, Human, Human, pickUp, SmallRock, bottomOf, RockPile, Human, drop, SmallRock, leftSideOf, Field, Human, moveTo, topOf RockPile, Robot, Human, pickUp, SmallRock, topOf RockPile, Human, SmallRock, drop, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 49
# situation: SmallRock, LargeRock, Robot, Human, Victim, topOf RockPile
# actions: Human, pickUp, SmallRock, topOf RockPile, Human, drop, SmallRock, topOf, Victim, Robot, moveTo, topOf RockPile, Robot, pickUp, LargeRock, topOf RockPile, Robot, LargeRock, moveTo, Human
# ----------------------------------------------------------------------------------------
#
# case 50
# situation: LargeRock, SmallRock, Human, Robot, leftSideOf, RockPile
# actions: Human, moveTo, leftSideOf, RockPile, Robot, moveTo, leftSideOf, RockPile, Human, hasState, standStill, LargeRock, topOf, leftSideOf, RockPile, LargeRock, Robot, break, leftSideOf, RockPile, Human, drop, SmallRock, leftSideOf, Field, Robot, moveTo, Human, Human, hasState, standStill, leftSideOf, RockPile, SmallRock, Robot, break, LargeRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 51
# situation: SmallRock, LargeRock, topOf RockPile, Robot, Human
# actions: Human, pickUp, SmallRock, bottomOf, RockPile, Robot, pickUp, LargeRock, topOf RockPile, Robot, Human, drop, LargeRock, SmallRock, leftSideOf, Field, Robot, SmallRock, topOf RockPile, pickUp, Robot, drop, SmallRock, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 52
# situation: LargeRock, Human, bottomOf, RockPile, Victim
# actions: Human, moveTo, LargeRock, topOf, Victim, Human, hasState, standStill, topOf, LargeRock, topOf, Victim, Robot, moveTo, Human, Robot, pickUp, LargeRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 53
# situation: SmallRock, leftSideOf, RockPile, Human, Robot
# actions: Human, pickUp, SmallRock, bottomOf, RockPile, Robot, pickUp, LargeRock, topOf RockPile, Human, Robot, drop, LargeRock, SmallRock, leftSideOf, Field, Robot, drop, LargeRock, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 54
# situation: LargeRock, Human, Robot, bottomOf, RockPile, leftSideOf, RockPile
# actions: LargeRock, Human, hasState, MoveBackAndForth , topOf, bottomOf, RockPile, Robot, moveTo, Human, Robot, pickUp, LargeRock, bottomOf, RockPile, Robot, drop, LargeRock, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 55
# situation: topOf RockPile, LargeRock
# actions: Robot, break, LargeRock, topOf RockPile, Human, pickUp, SmallRock, Robot, moveTo, SmallRock
# ----------------------------------------------------------------------------------------
#
# case 56
# situation: SmallRock, topOf RockPile
# actions: Human, SmallRock, pickUp, leftSideOf, Field, Human, pickUp, SmallRock, topOf RockPile, Human, drop, SmallRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 57
# situation: LargeRock, SmallRock, Robot, Human, above, RockPile
# actions: Human, pickUp, SmallRock, Robot, pickUp, LargeRock, Human, Robot, moveTo, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 58
# situation: SmallRock, bottomOf, RockPile
# actions: Human, pickUp, SmallRock, bottomOf, RockPile, Robot, hasState, MoveBackAndForth , leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 59
# situation: LargeRock, leftSideOf, RockPile
# actions: Human, moveTo, LargeRock, leftSideOf, RockPile, Robot, break, LargeRock, leftSideOf, RockPile, Human, Robot, pickUp, SmallRock, leftSideOf, RockPile, Robot, Human, drop, SmallRock, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 60
# situation: LargeRock, leftSideOf, RockPile, SmallRock, bottomOf, RockPile
# actions: Robot, break, LargeRock, leftSideOf, RockPile, Human, pickUp, SmallRock, moveTo, leftSideOf, RockPile, Robot, moveTo, SmallRock, drop, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 61
# situation: SmallRock, bottomOf, RockPile
# actions: Human, pickUp, SmallRock, bottomOf, RockPile, Robot, break, above, RockPile, LargeRock, Human, pickUp, SmallRock, above, RockPile, Human, drop, SmallRock, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 62
# situation: SmallRock, LargeRock, topOf, Victim
# actions: Human, pickUp, SmallRock, Human, drop, SmallRock, topOf, Victim, Robot, LargeRock, pickUp, Robot, drop, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 63
# situation: leftSideOf, RockPile, LargeRock, SmallRock, Robot, Human, break
# actions: Human, pickUp, SmallRock, leftSideOf, RockPile, Human, drop, SmallRock, leftSideOf, Field, Robot, break, LargeRock, leftSideOf, RockPile, Human, pickUp, SmallRock, Human, drop, leftSideOf, Field, SmallRock
# ----------------------------------------------------------------------------------------
#
# case 64
# situation: SmallRock, Human, Robot, leftSideOf, Field, rightSideOf, Field
# actions: Human, pickUp, SmallRock, leftSideOf, RockPile, Robot, pickUp, SmallRock, topOf RockPile, Robot, drop, SmallRock, rightSideOf, Field, Robot, drop, SmallRock, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 65
# situation: LargeRock, bottomOf, RockPile
# actions: Human, moveTo, LargeRock, bottomOf, RockPile, Human, hasState, standStill, bottomOf, RockPile, Robot, pickUp, LargeRock
# ----------------------------------------------------------------------------------------
#
# case 66
# situation: LargeRock, SmallRock, Robot, Human, leftSideOf, Field, rightSideOf, Field
# actions: Robot, pickUp, LargeRock, drop, Robot, leftSideOf, Field, Human, SmallRock, pickUp, leftSideOf, Field, Human, drop, SmallRock, Robot, pickUp, LargeRock, Robot, drop, rightSideOf, Field, LargeRock
# ----------------------------------------------------------------------------------------
#
# case 67
# situation: LargeRock, bottomOf, RockPile, Robot, Human
# actions: Human, hasState, standStill, bottomOf, RockPile, Robot, moveTo, LargeRock, Robot, pickUp, LargeRock, Robot, drop, LargeRock, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 68
# situation: topOf RockPile, LargeRock
# actions: Robot, break, LargeRock, topOf RockPile
# ----------------------------------------------------------------------------------------
#
# case 69
# situation: LargeRock, topOf, Victim
# actions: Robot, break, LargeRock, topOf, Victim, drop, SmallRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 70
# situation: topOf RockPile, SmallRock
# actions: Human, pickUp, SmallRock, topOf RockPile, Robot, pickUp, SmallRock, topOf RockPile
# ----------------------------------------------------------------------------------------
#
# case 71
# situation: topOf RockPile, SmallRock
# actions: Human, pickUp, SmallRock, topOf RockPile
# ----------------------------------------------------------------------------------------
#
# case 72
# situation: Human, SmallRock
# actions: moveTo, leftSideOf, RockPile, drop, SmallRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 73
# situation: topOf RockPile, LargeRock
# actions: Robot, pickUp, LargeRock, topOf RockPile
# ----------------------------------------------------------------------------------------
#
# case 74
# situation: Robot, LargeRock
# actions: moveTo, leftSideOf, RockPile, drop, LargeRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 75
# situation: Robot, SmallRock
# actions: moveTo, leftSideOf, RockPile, drop, leftSideOf, RockPile, SmallRock
# ----------------------------------------------------------------------------------------
#
# case 76
# situation: bottomOf, RockPile, SmallRock
# actions: Human, pickUp, SmallRock, bottomOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 77
# situation: bottomOf, RockPile, LargeRock
# actions: Robot, break, LargeRock, bottomOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 78
# situation: bottomOf, RockPile, SmallRock
# actions: Robot, pickUp, SmallRock, bottomOf, RockPile, Human, pickUp, SmallRock, bottomOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 79
# situation: Robot, LargeRock
# actions: moveTo, rightSideOf, RockPile, drop, LargeRock, rightSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 80
# situation: SmallRock, leftSideOf, RockPile
# actions: Human, pickUp, SmallRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 81
# situation: LargeRock, topOf, SmallRock
# actions: Robot, break, LargeRock, bottomOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 82
# situation: Human, SmallRock
# actions: moveTo, rightSideOf, RockPile, drop, SmallRock, rightSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 83
# situation: Human, pickUp, SmallRock, bottomOf, RockPile
# actions: Robot, hasState, MoveBackAndForth , bottomOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 84
# situation: Human, SmallRock
# actions: moveTo, Victim, drop, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 85
# situation: Human, moveTo, LargeRock
# actions: Robot, break, LargeRock, topOf, Human
# ----------------------------------------------------------------------------------------
#
# case 86
# situation: SmallRock, topOf, Victim
# actions: Human, pickUp, SmallRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 87
# situation: Robot, SmallRock
# actions: moveTo, rightSideOf, RockPile, drop, rightSideOf, RockPile, SmallRock
# ----------------------------------------------------------------------------------------
#
# case 88
# situation: Human, moveTo, LargeRock
# actions: Robot, hasState, standStill, topOf, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 89
# situation: bottomOf, RockPile, LargeRock
# actions: Robot, pickUp, LargeRock, bottomOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 90
# situation: Human, moveTo, LargeRock
# actions: Robot, pickUp, LargeRock, topOf, Human
# ----------------------------------------------------------------------------------------
#
# case 91
# situation: LargeRock, topOf RockPile, LargeRock, above, RockPile, Victim, one
# actions: Human, pickUp, SmallRock, Human, drop, SmallRock, Robot, break, LargeRock, Robot, break, LargeRock, SmallRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 92
# situation: SmallRock, topOf RockPile
# actions: Human, pickUp, SmallRock, Robot, hasState, standStill
# ----------------------------------------------------------------------------------------
#
# case 93
# situation: LargeRock, topOf RockPile, LargeRock, leftSideOf, RockPile
# actions: Human, moveTo, LargeRock, leftSideOf, Field, Robot, moveTo, LargeRock, leftSideOf, Field, Robot, break
# ----------------------------------------------------------------------------------------
#
# case 94
# situation: SmallRock, LargeRock, topOf, Victim
# actions: Human, pickUp, SmallRock, leftSideOf, RockPile, Robot, moveTo, Human
# ----------------------------------------------------------------------------------------
#
# case 95
# situation: LargeRock, topOf RockPile, LargeRock, leftSideOf, RockPile, SmallRock, leftSideOf, RockPile
# actions: Human, hasState, MoveBackAndForth , rightSideOf, Field, Robot, drop, LargeRock, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 96
# situation: LargeRock, leftSideOf, RockPile
# actions: Human, moveTo, LargeRock, leftSideOf, RockPile, Human, hasState, standStill, Robot, pickUp, LargeRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 97
# situation: LargeRock, above, RockPile, SmallRock, topOf, Victim
# actions: Human, moveTo, leftSideOf, RockPile, Robot, moveTo, Human, Robot, break, LargeRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 98
# situation: LargeRock, topOf, SmallRock, leftSideOf, RockPile, SmallRock, topOf, Victim
# actions: Human, moveTo, SmallRock, topOf, Robot, moveTo, Human, moveTo, SmallRock, leftSideOf, RockPile, Robot, break, LargeRock
# ----------------------------------------------------------------------------------------
#
# case 99
# situation: SmallRock, topOf RockPile, LargeRock, topOf RockPile, Victim
# actions: Human, pickUp, SmallRock, topOf RockPile, Human, drop, SmallRock, topOf, Victim, Robot, pickUp, LargeRock, topOf RockPile, Robot, moveTo, Human
# ----------------------------------------------------------------------------------------
#
# case 100
# situation: LargeRock, topOf RockPile, LargeRock, leftSideOf, RockPile, SmallRock, leftSideOf, RockPile
# actions: Robot, moveTo, Human, Human, moveTo, LargeRock, topOf RockPile, Human, hasState, standStill, Robot, break, LargeRock, topOf RockPile
# ----------------------------------------------------------------------------------------
#
# case 101
# situation: LargeRock, topOf RockPile, SmallRock, bottomOf, RockPile
# actions: Robot, pickUp, LargeRock, topOf RockPile, Human, pickUp, SmallRock, bottomOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 102
# situation: LargeRock, topOf, Victim
# actions: Human, moveTo, LargeRock, topOf, Victim, Human, hasState, standStill, Robot, moveTo, Human, Robot, break, LargeRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 103
# situation: LargeRock, topOf RockPile, SmallRock, bottomOf, RockPile
# actions: Robot, pickUp, LargeRock, topOf RockPile, Human, pickUp, SmallRock, bottomOf, RockPile, Human, drop, leftSideOf, Field, Robot, drop, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 104
# situation: LargeRock, leftSideOf, RockPile
# actions: Human, moveTo, LargeRock, leftSideOf, RockPile, Human, hasState, standStill, Human, hasState, MoveBackAndForth , Robot, pickUp, LargeRock, leftSideOf, RockPile, Robot, drop, LargeRock, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 105
# situation: LargeRock, topOf RockPile, Robot, Human, bottomOf, RockPile, SmallRock
# actions: break, pickUp
# ----------------------------------------------------------------------------------------
#
# case 106
# situation: Human, SmallRock, topOf RockPile
# actions: pickUp
# ----------------------------------------------------------------------------------------
#
# case 107
# situation: Robot, Human, LargeRock, SmallRock
# actions: pickUp, drop
# ----------------------------------------------------------------------------------------
#
# case 108
# situation: LargeRock, leftSideOf, RockPile, Robot, Human
# actions: break
# ----------------------------------------------------------------------------------------
#
# case 109
# situation: SmallRock, Human, Robot, bottomOf, RockPile
# actions: pickUp
# ----------------------------------------------------------------------------------------
#
# case 110
# situation: Robot, Human, SmallRock, topOf RockPile
# actions: hasState, standStill
# ----------------------------------------------------------------------------------------
#
# case 111
# situation: LargeRock, Robot, topOf RockPile
# actions: pickUp
# ----------------------------------------------------------------------------------------
#
# case 112
# situation: LargeRock, topOf RockPile, Robot, bottomOf, RockPile
# actions: pickUp, break
# ----------------------------------------------------------------------------------------
#
# case 113
# situation: LargeRock, Robot, leftSideOf, RockPile
# actions: pickUp
# ----------------------------------------------------------------------------------------
#
# case 114
# situation: LargeRock, Robot, leftSideOf, RockPile
# actions: pickUp
# ----------------------------------------------------------------------------------------
#
# case 115
# situation: topOf RockPile, LargeRock
# actions: Human, pickUp, LargeRock, topOf RockPile, Robot, break, LargeRock, topOf RockPile, Robot, break, LargeRock, topOf RockPile
# ----------------------------------------------------------------------------------------
#
# case 116
# situation: topOf RockPile, LargeRock
# actions: Robot, break, LargeRock, topOf RockPile, all
# ----------------------------------------------------------------------------------------
#
# case 117
# situation: topOf RockPile, SmallRock
# actions: Human, pickUp, SmallRock, topOf RockPile, drop, SmallRock, leftSideOf, Field, all
# ----------------------------------------------------------------------------------------
#
# case 118
# situation: topOf RockPile, LargeRock
# actions: Robot, pickUp, LargeRock, topOf RockPile, drop, LargeRock, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 119
# situation: topOf RockPile, LargeRock, leftSideOf, RockPile, LargeRock
# actions: Robot, break, LargeRock, leftSideOf, RockPile, pickUp, SmallRock, leftSideOf, RockPile, Human, drop, SmallRock, leftSideOf, Field, Human
# ----------------------------------------------------------------------------------------
#
# case 120
# situation: LargeRock, topOf RockPile
# actions: Robot, hasState, standStill, topOf RockPile, Human, hasState, standStill, topOf RockPile
# ----------------------------------------------------------------------------------------
#
# case 121
# situation: LargeRock, leftSideOf, RockPile
# actions: Robot, hasState, standStill, leftSideOf, RockPile, Human, hasState, standStill, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 122
# situation: topOf RockPile, SmallRock
# actions: Human, pickUp, SmallRock, topOf RockPile, drop, SmallRock, leftSideOf, Field, one
# ----------------------------------------------------------------------------------------
#
# case 123
# situation: SmallRock, leftSideOf, RockPile
# actions: Human, pickUp, SmallRock, leftSideOf, RockPile, drop, SmallRock, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 124
# situation: LargeRock, leftSideOf, RockPile
# actions: Robot, hasState, standStill, leftSideOf, RockPile, Robot, pickUp, LargeRock, leftSideOf, RockPile, Robot, drop, LargeRock, rightSideOf, Field, Robot, hasState, standStill, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 125
# situation: leftSideOf, RockPile, SmallRock
# actions: Human, pickUp, SmallRock, leftSideOf, RockPile, Human, drop, SmallRock, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 126
# situation: bottomOf, RockPile, SmallRock
# actions: Human, pickUp, SmallRock, bottomOf, RockPile, drop, SmallRock, leftSideOf, Field, one
# ----------------------------------------------------------------------------------------
#
# case 127
# situation: leftSideOf, RockPile, SmallRock
# actions: Human, pickUp, leftSideOf, RockPile, SmallRock, Human, drop, SmallRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 128
# situation: bottomOf, RockPile, SmallRock
# actions: Human, pickUp, SmallRock, bottomOf, RockPile, Human, drop, SmallRock, rightSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 129
# situation: leftSideOf, RockPile, SmallRock
# actions: Human, pickUp, leftSideOf, RockPile, SmallRock, Human, drop, SmallRock, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 130
# situation: LargeRock, leftSideOf, RockPile
# actions: Robot, leftSideOf, RockPile, break, LargeRock
# ----------------------------------------------------------------------------------------
#
# case 131
# situation: LargeRock, topOf RockPile
# actions: Robot, break, LargeRock, topOf RockPile, Robot, pickUp, SmallRock, topOf RockPile, Robot, drop, SmallRock, bottomOf, RockPile, one
# ----------------------------------------------------------------------------------------
#
# case 132
# situation: SmallRock, topOf RockPile
# actions: Human, pickUp, SmallRock, topOf RockPile, Human, drop, SmallRock, bottomOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 133
# situation: topOf RockPile, LargeRock, topOf RockPile, LargeRock
# actions: Robot, break, LargeRock, topOf RockPile, Human, hasState, standStill, topOf RockPile, Robot, break, LargeRock, topOf RockPile
# ----------------------------------------------------------------------------------------
#
# case 134
# situation: LargeRock, topOf RockPile
# actions: Robot, pickUp, topOf RockPile, LargeRock, Robot, drop, LargeRock, leftSideOf, Field, above, RockPile
# ----------------------------------------------------------------------------------------
#
# case 135
# situation: SmallRock, topOf RockPile
# actions: Robot, pickUp, SmallRock, topOf RockPile, Robot, drop, SmallRock, rightSideOf, Field, above, RockPile, all
# ----------------------------------------------------------------------------------------
#
# case 136
# situation: LargeRock, leftSideOf, RockPile
# actions: Human, hasState, standStill, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 137
# situation: LargeRock, leftSideOf, RockPile
# actions: Human, hasState, standStill, leftSideOf, RockPile, Robot, break, LargeRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 138
# situation: topOf RockPile, LargeRock
# actions: Human, pickUp, LargeRock, topOf RockPile, Robot, break, LargeRock, topOf RockPile, Robot, break, LargeRock, topOf RockPile
# ----------------------------------------------------------------------------------------
#
# case 139
# situation: SmallRock, rightSideOf, RockPile
# actions: Human, pickUp, rightSideOf, RockPile, SmallRock, Human, moveTo, leftSideOf, Field, Human, moveTo, rightSideOf, Field, Human, drop, SmallRock, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 140
# situation: LargeRock, leftSideOf, RockPile
# actions: Robot, pickUp, LargeRock, leftSideOf, RockPile, drop, LargeRock, rightSideOf, Field, above, RockPile
# ----------------------------------------------------------------------------------------
#
# case 141
# situation: LargeRock, leftSideOf, RockPile
# actions: Human, hasState, standStill, leftSideOf, RockPile, Robot, LargeRock, leftSideOf, RockPile, pickUp, Robot, drop, rightSideOf, Field, above, RockPile, LargeRock
# ----------------------------------------------------------------------------------------
#
# case 142
# situation: LargeRock, leftSideOf, RockPile
# actions: Human, hasState, standStill, leftSideOf, RockPile, Robot, LargeRock, leftSideOf, RockPile, pickUp
# ----------------------------------------------------------------------------------------
#
# case 143
# situation: LargeRock, topOf RockPile, topOf, LargeRock
# actions: Robot, break, LargeRock, topOf RockPile, Human, pickUp, SmallRock, topOf RockPile
# ----------------------------------------------------------------------------------------
#
# case 144
# situation: LargeRock, topOf, LargeRock, topOf, Victim, SmallRock, topOf, LargeRock
# actions: Human, pickUp, SmallRock, topOf RockPile, Robot, hasState, standStill, rightSideOf, Field, Victim, hasState, standStill, bottomOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 145
# situation: LargeRock, topOf, Victim
# actions: Robot, hasState, MoveBackAndForth , topOf, Human, Robot, break, LargeRock, leftSideOf, RockPile, Human, pickUp, SmallRock, leftSideOf, RockPile, Robot, hasState, standStill, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 146
# situation: LargeRock, topOf, Victim
# actions: Robot, break, LargeRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 147
# situation: SmallRock, topOf, Victim
# actions: Human, pickUp, topOf RockPile, bottomOf, RockPile, SmallRock, drop, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 148
# situation: LargeRock, topOf, Victim
# actions: Robot, break, LargeRock, topOf, Victim, Human, pickUp, SmallRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 149
# situation: LargeRock, SmallRock, topOf RockPile, topOf, LargeRock
# actions: Robot, pickUp, LargeRock, topOf RockPile, Human, pickUp, SmallRock, topOf RockPile, Robot, pickUp, LargeRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 150
# situation: SmallRock, topOf, LargeRock, leftSideOf, RockPile
# actions: Robot, pickUp, SmallRock, topOf, LargeRock, Robot, drop, SmallRock, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 151
# situation: LargeRock, leftSideOf, RockPile
# actions: Robot, pickUp, LargeRock, leftSideOf, RockPile, Robot, drop, LargeRock, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 152
# situation: SmallRock, topOf, Victim, topOf RockPile
# actions: Human, hasState, standStill, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 153
# situation: LargeRock, topOf, Victim
# actions: Robot, break, LargeRock, topOf, Victim, SmallRock, drop, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 154
# situation: SmallRock, topOf, Victim
# actions: Human, pickUp, SmallRock, topOf RockPile, topOf, Victim, Human, drop, SmallRock, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 155
# situation: Human, hasState, MoveBackAndForth , LargeRock, leftSideOf, RockPile
# actions: Robot, hasState, MoveBackAndForth , above, RockPile, Robot, break, LargeRock, leftSideOf, RockPile
# ----------------------------------------------------------------------------------------
#
# case 156
# situation: LargeRock, topOf, Victim
# actions: Human, pickUp, SmallRock, leftSideOf, RockPile, Robot, hasState, MoveBackAndForth , leftSideOf, RockPile, Human, drop, SmallRock, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 157
# situation: LargeRock, leftSideOf, RockPile
# actions: Human, hasState, MoveBackAndForth , topOf, LargeRock, Robot, break, LargeRock
# ----------------------------------------------------------------------------------------
#
# case 158
# situation: SmallRock, LargeRock, topOf, Victim
# actions: Human, pickUp, SmallRock, topOf RockPile, Human, drop, SmallRock, topOf, Victim, Robot, pickUp, LargeRock, topOf RockPile, Robot, drop, LargeRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 159
# situation: SmallRock, LargeRock, topOf RockPile, topOf, Victim
# actions: Human, hasState, MoveBackAndForth , topOf, LargeRock, topOf RockPile, Robot, break, LargeRock, topOf RockPile
# ----------------------------------------------------------------------------------------
#
# case 160
# situation: SmallRock, topOf RockPile, LargeRock, topOf, Victim
# actions: Robot, hasState, MoveBackAndForth , topOf, Human, Robot, break, LargeRock, leftSideOf, RockPile, Human, pickUp, SmallRock, topOf RockPile, Robot, break, LargeRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 161
# situation: SmallRock, LargeRock, topOf RockPile, leftSideOf, RockPile
# actions: Robot, pickUp, LargeRock, topOf RockPile, Robot, drop, LargeRock, leftSideOf, Field, Robot, pickUp, SmallRock, topOf RockPile, Robot, drop, SmallRock, rightSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 162
# situation: LargeRock, topOf, Victim
# actions: Human, moveTo, LargeRock, topOf, Victim, Robot, moveTo, LargeRock, topOf, Victim, Robot, pickUp, LargeRock, topOf, Victim
# ----------------------------------------------------------------------------------------
#
# case 163
# situation: SmallRock, LargeRock, topOf RockPile, topOf, LargeRock, leftSideOf, RockPile
# actions: Robot, pickUp, SmallRock, leftSideOf, RockPile, Robot, drop, SmallRock, leftSideOf, Field, Robot, pickUp, LargeRock, leftSideOf, RockPile, Robot, drop, LargeRock, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 164
# situation: SmallRock, leftSideOf, RockPile, SmallRock, topOf, Victim
# actions: Human, pickUp, SmallRock, leftSideOf, RockPile, Human, drop, SmallRock, leftSideOf, Field, Human, pickUp, SmallRock, topOf, Victim, Human, drop, SmallRock, leftSideOf, Field
# ----------------------------------------------------------------------------------------
#
# case 165
# situation: LargeRock, leftSideOf, RockPile
# actions: Human, topOf, LargeRock, leftSideOf, RockPile, Robot, pickUp, LargeRock, leftSideOf, RockPile, Robot, drop, LargeRock, rightSideOf, Field
# ----------------------------------------------------------------------------------------

# %%
import rdflib

# Create a new RDF graph
g = rdflib.Graph()

# Parse an OWL file
g.parse("coLearningOntology.owl", format="application/rdf+xml")

# Iterate over each statement in the graph
for stmt in g:
    print(stmt)

# You can also query the graph using SPARQL
query = """
SELECT ?subject ?predicate ?object
WHERE {
  # ?subject ?predicate ?object
}
LIMIT 10
"""

for row in g.query(query):
    print(row)
# Out:
# (rdflib.term.URIRef('http://example.org/coLearningOntology#ActorAction'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.BNode('N6c7ad248ef694a9499d6aaecd42be6f9'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'), rdflib.term.BNode('Nd46862656df0449da8eb41743480e951'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#Actor'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#Victim'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#Field'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#leftSideOf'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#moveTo'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#above'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#bottomOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/coLearningOntology#RockPile'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Ontology'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#hasState'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/coLearningOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#LargeRock'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#ObjectExceptField'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#unionOf'), rdflib.term.BNode('N6c7ad248ef694a9499d6aaecd42be6f9'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#drop'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.BNode('Nd46862656df0449da8eb41743480e951'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'), rdflib.term.BNode('N7579cea9ffa84f9cb90f9b0e5b652d96'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#rightSideOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/coLearningOntology#ActorOrObject'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#bottomOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/coLearningOntology#ActorOrObject'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#Human'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.BNode('N29486f6fbaa44355a6fa8e11fe584357'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'), rdflib.term.URIRef('http://example.org/coLearningOntology#RockPile'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#Object'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#RockPileOrField'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#moveTo'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/coLearningOntology#Object'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#pickUp'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.BNode('N6c7ad248ef694a9499d6aaecd42be6f9'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'), rdflib.term.URIRef('http://example.org/coLearningOntology#RockPile'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#StandStill'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#break'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/coLearningOntology#Object'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#drop'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/coLearningOntology#Object'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#above'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/coLearningOntology#ActorOrObject'))
# (rdflib.term.BNode('Neeb0acbe45ad4c25b720ad0181918dc3'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'), rdflib.term.URIRef('http://example.org/coLearningOntology#Field'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#pickUp'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/coLearningOntology#Object'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#MoveBackAndForth'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#RockPile'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/coLearningOntology#Object'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#pickUp'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/coLearningOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#Victim'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/coLearningOntology#Actor'))
# (rdflib.term.BNode('N29486f6fbaa44355a6fa8e11fe584357'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'), rdflib.term.BNode('Neeb0acbe45ad4c25b720ad0181918dc3'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#rightSideOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/coLearningOntology#RockPileOrField'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#versionInfo'), rdflib.term.Literal('1.0'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#topOf'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#Robot'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#Robot'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/coLearningOntology#Actor'))
# (rdflib.term.BNode('N68bd0c3322d346e89c65a2e8a6fd6d5a'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'), rdflib.term.URIRef('http://example.org/coLearningOntology#BrownRock'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#RockPile'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#topOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/coLearningOntology#ObjectExceptField'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#MoveBackAndForth'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/coLearningOntology#ActorAction'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#StandStill'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/coLearningOntology#ActorAction'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#hasState'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#ObjectExceptField'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#BrownRock'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/coLearningOntology#Object'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#bottomOf'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#hasState'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/coLearningOntology#ActorAction'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#topOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/coLearningOntology#ActorOrObject'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#SmallRock'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/coLearningOntology#Object'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#break'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#above'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/coLearningOntology#RockPile'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#Human'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/coLearningOntology#Actor'))
# (rdflib.term.BNode('N94e3af04bf3a468682fbdd9919d0adbc'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'), rdflib.term.URIRef('http://example.org/coLearningOntology#Object'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#rightSideOf'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.BNode('N94e3af04bf3a468682fbdd9919d0adbc'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'))
# (rdflib.term.BNode('Ne99867b1895a45c4856f0a2c9be9ce38'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'), rdflib.term.BNode('N94e3af04bf3a468682fbdd9919d0adbc'))
# (rdflib.term.BNode('N7579cea9ffa84f9cb90f9b0e5b652d96'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'), rdflib.term.BNode('N68bd0c3322d346e89c65a2e8a6fd6d5a'))
# (rdflib.term.BNode('Nd46862656df0449da8eb41743480e951'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'), rdflib.term.URIRef('http://example.org/coLearningOntology#LargeRock'))
# (rdflib.term.BNode('N7579cea9ffa84f9cb90f9b0e5b652d96'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'), rdflib.term.URIRef('http://example.org/coLearningOntology#SmallRock'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#ActorOrObject'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#RockPileOrField'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#unionOf'), rdflib.term.BNode('N29486f6fbaa44355a6fa8e11fe584357'))
# (rdflib.term.BNode('N68bd0c3322d346e89c65a2e8a6fd6d5a'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#leftSideOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/coLearningOntology#ActorOrObject'))
# (rdflib.term.BNode('Neeb0acbe45ad4c25b720ad0181918dc3'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#drop'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/coLearningOntology#Actor'))
# (rdflib.term.BNode('Ne99867b1895a45c4856f0a2c9be9ce38'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'), rdflib.term.URIRef('http://example.org/coLearningOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#BrownRock'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#Field'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/coLearningOntology#Object'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#moveTo'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/coLearningOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#leftSideOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/coLearningOntology#RockPileOrField'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#SmallRock'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#ActorOrObject'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#unionOf'), rdflib.term.BNode('Ne99867b1895a45c4856f0a2c9be9ce38'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#break'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/coLearningOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#LargeRock'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/coLearningOntology#Object'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#ActorAction'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.BNode('N6c7ad248ef694a9499d6aaecd42be6f9'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'), rdflib.term.BNode('Nd46862656df0449da8eb41743480e951'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#Actor'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#Victim'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#Field'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#leftSideOf'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#moveTo'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#above'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology#bottomOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/coLearningOntology#RockPile'))
# (rdflib.term.URIRef('http://example.org/coLearningOntology'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Ontology'))

# %%
from rdflib import Graph, Namespace, RDF, URIRef
from rdflib.namespace import RDFS, OWL

# Create a new RDF graph
g = Graph()

# Namespace for our ontology
EX = Namespace("http://example.org/myOntology#")

# Bind a prefix to our namespace for more readable output
g.bind("ex", EX)

# Add classes (types) to the graph
robot = URIRef(EX.Robot)
human = URIRef(EX.Human)
large_rock = URIRef(EX.LargeRock)

# Add individuals to the graph
robot1 = URIRef(EX.robot1)
human1 = URIRef(EX.human1)
rock1 = URIRef(EX.rock1)

# Type assertions
g.add((robot1, RDF.type, robot))
g.add((human1, RDF.type, human))
g.add((rock1, RDF.type, large_rock))

# Add relationships
g.add((human1, EX.pickUp, rock1))
g.add((robot1, EX.moveTo, rock1))

# # Serialize the graph in RDF/XML format
# print(g.serialize(format="xml").decode("u8"))

# Or save the graph to a file
# with open("example_graph.rdf", "wb") as f:
#     g.serialize(f, format="xml")

# %%
g.serialize("example_graph.rdf", format="xml")
