# %% [markdown]
# ## Parse data

# %%
import warnings
from typing import List
import math

import pandas as pd
from glob import glob
import re
from bs4 import BeautifulSoup

warnings.filterwarnings("ignore", category=DeprecationWarning)

# Get a list of all xlsx files
files = sorted(glob("CPs exp 2a data/*.xlsx"))

# all_string_values = []
situations = []
actions = []

print(f"number of files: {len(files)}\n")
# Loop through the list of files and read each file
for file in files:
    print(f"processing `{file}` ...")
    dataframe = pd.read_excel(file)
    dataframe.drop_duplicates(subset="name", keep="last", inplace=True)
    # Now you can do something with the data
    assert len(dataframe.situation) == len(dataframe.actions)
    print(
        f"There are in total of {len(dataframe.situation)} situation-action pairs "
        f"in the file {file}.\n"
    )

    for situation, action in zip(dataframe.situation, dataframe.actions):
        # Parse HTML content
        situation_parsed = []

        if isinstance(situation, float) and math.isnan(situation):
            situation_parsed = None

        else:
            soup = BeautifulSoup(situation, "html.parser")

            # Extract data
            for div in soup.find_all("div", class_="item"):
                # Extract class and text content

                class_name = (
                    div.get("class")[1]
                    if len(div.get("class")) > 1
                    else div.get("class")[0]
                )
                # Process the text content more carefully to add spaces around buttons
                # or special divs
                texts = div.find_all(text=True)
                text_content = " ".join(text.strip() for text in texts).strip().lower()
                situation_parsed.append((class_name, text_content))

        situations.append(situation_parsed)

        soup = BeautifulSoup(action, "html.parser")
        action_parsed = {}

        # Extract boxes
        boxes = soup.find_all("div", class_="box box_action")

        for box in boxes:
            box_id = box.get("id")
            action_parsed[box_id] = []

            items = box.find_all("div", class_="item")
            for item in items:
                class_name = (
                    item.get("class")[1]
                    if len(item.get("class")) > 1
                    else item.get("class")[0]
                )
                # Process the text content more carefully to add spaces around buttons
                # or special divs
                texts = item.find_all(text=True)
                text_content = " ".join(text.strip() for text in texts).strip().lower()
                action_parsed[box_id].append((class_name, text_content))

        actions.append(action_parsed)
        assert len(situations) == len(actions)

situation_action_pairs = list(zip(situations, actions))

print(
    f"In total of {len(situation_action_pairs)} situation-action pairs have "
    f"been processed.\n"
)

# Create a new list with elements that don't have None as the situation
situation_action_pairs = [
    (situation, action)
    for situation, action in situation_action_pairs
    if situation is not None
]
print(
    f"After removing None, now there is {len(situation_action_pairs)} "
    f"situation-action pairs.\n"
)

for idx, (situation, actions_dict) in enumerate(situation_action_pairs.copy()):
    actions_list = []
    for action in actions_dict.values():
        if action:
            actions_list.append(action)

    if actions_list:
        situation_action_pairs[idx] = situation, actions_list

print(
    f"After removing empty actions, now there is {len(situation_action_pairs)} "
    f"situation-action pairs.\n"
)
# Out:
# number of files: 10
#
# processing `CPs exp 2a data/p01_interaction_patterns.xlsx` ...
# There are in total of 14 situation-action pairs in the file CPs exp 2a data/p01_interaction_patterns.xlsx.
#
# processing `CPs exp 2a data/p03_interaction_patterns.xlsx` ...
# There are in total of 15 situation-action pairs in the file CPs exp 2a data/p03_interaction_patterns.xlsx.
#
# processing `CPs exp 2a data/p04_interaction_patterns.xlsx` ...
# There are in total of 13 situation-action pairs in the file CPs exp 2a data/p04_interaction_patterns.xlsx.
#
# processing `CPs exp 2a data/p05_interaction_patterns.xlsx` ...
# There are in total of 14 situation-action pairs in the file CPs exp 2a data/p05_interaction_patterns.xlsx.
#
# processing `CPs exp 2a data/p06_interaction_patterns.xlsx` ...
# There are in total of 13 situation-action pairs in the file CPs exp 2a data/p06_interaction_patterns.xlsx.
#
# processing `CPs exp 2a data/p07_interaction_patterns.xlsx` ...
# There are in total of 23 situation-action pairs in the file CPs exp 2a data/p07_interaction_patterns.xlsx.
#
# processing `CPs exp 2a data/p09_interaction_patterns.xlsx` ...
# There are in total of 14 situation-action pairs in the file CPs exp 2a data/p09_interaction_patterns.xlsx.
#
# processing `CPs exp 2a data/p13_interaction_patterns.xlsx` ...
# There are in total of 10 situation-action pairs in the file CPs exp 2a data/p13_interaction_patterns.xlsx.
#
# processing `CPs exp 2a data/p14_interaction_patterns.xlsx` ...
# There are in total of 28 situation-action pairs in the file CPs exp 2a data/p14_interaction_patterns.xlsx.
#
# processing `CPs exp 2a data/p15_interaction_patterns.xlsx` ...
# There are in total of 23 situation-action pairs in the file CPs exp 2a data/p15_interaction_patterns.xlsx.
#
# In total of 167 situation-action pairs have been processed.
#
# After removing None, now there is 166 situation-action pairs.
#
# After removing empty actions, now there is 166 situation-action pairs.

# %% [markdown]
# ## Get the stats of situations and actions

# %%
from collections import Counter

unique_ = dict(
    Counter([s for situation, actions in situation_action_pairs for s in situation])
)
unique_ = dict(sorted(unique_.items(), key=lambda item: item[1], reverse=True))
unique_
# Out:
# {('objects', 'large rock'): 140,
#  ('objects', 'small rock'): 102,
#  ('locations', 'top of rock pile'): 79,
#  ('locations', 'left side of rock pile'): 59,
#  ('agents', 'victim'): 33,
#  ('agents', 'human'): 31,
#  ('locations', 'bottom of rock pile'): 29,
#  ('agents', 'robot'): 29,
#  ('locations', 'on top of actor'): 28,
#  ('locations', 'on top of object'): 13,
#  ('counters', 'all'): 8,
#  ('counters', 'one'): 7,
#  ('locations', 'left side of field'): 3,
#  ('locations', 'above rock pile'): 3,
#  ('actions', 'move to object'): 3,
#  ('locations', 'right side of rock pile'): 2,
#  ('locations', 'right side of field'): 2,
#  ('objects', 'brown rock'): 1,
#  ('actions', 'break object in location'): 1,
#  ('actions', 'pick up object in location'): 1,
#  ('actions', 'move back and forth in location'): 1}

# %%
unique_ = dict(
    Counter(
        [
            a
            for situation, actions in situation_action_pairs
            for action in actions
            for a in action
        ]
    )
)
unique_ = dict(sorted(unique_.items(), key=lambda item: item[1], reverse=True))
unique_
# Out:
# {('agents', 'robot'): 226,
#  ('agents', 'human'): 208,
#  ('objects', 'large rock'): 181,
#  ('actions', 'pick up object in location'): 181,
#  ('objects', 'small rock'): 178,
#  ('locations', 'top of rock pile'): 90,
#  ('locations', 'left side of rock pile'): 88,
#  ('actions', 'drop object in location'): 86,
#  ('actions', 'break object in location'): 68,
#  ('locations', 'on top of actor'): 47,
#  ('agents', 'victim'): 46,
#  ('locations', 'left side of field'): 45,
#  ('locations', 'bottom of rock pile'): 35,
#  ('counters', 'all'): 35,
#  ('locations', 'right side of field'): 32,
#  ('actions', 'move to object'): 31,
#  ('actions', 'stand still in location'): 30,
#  ('actions', 'move back and forth in location'): 20,
#  ('counters', 'one'): 16,
#  ('actions', 'move to location'): 16,
#  ('actions', 'move to actor'): 13,
#  ('locations', 'right side of rock pile'): 12,
#  ('locations', 'on top of object'): 12,
#  ('locations', 'above rock pile'): 10,
#  ('counters', 'zero'): 2,
#  ('locations', 'on top of location'): 1}

# %%
for situation, actions in situation_action_pairs:
    print(situation)
    print(actions)
    print()
# Out:
# [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'bottom of rock pile'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'right side of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'bottom of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')]]
#
# [('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')]
# [[('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'move to object'), ('counters', 'zero'), ('objects', 'small rock')]]
#
# [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'small rock')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'right side of rock pile')]]
#
# [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'left side of rock pile'), ('objects', 'large rock'), ('locations', 'right side of rock pile'), ('objects', 'large rock'), ('agents', 'victim')]
# [[('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'right side of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'right side of rock pile')]]
#
# [('locations', 'bottom of rock pile'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'bottom of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('locations', 'bottom of rock pile'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'small rock')]]
#
# [('locations', 'left side of rock pile'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim'), ('objects', 'small rock')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('locations', 'on top of object'), ('objects', 'small rock'), ('objects', 'large rock')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock')]]
#
# [('objects', 'small rock'), ('locations', 'top of rock pile'), ('locations', 'top of rock pile'), ('objects', 'large rock')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'victim')]]
#
# [('locations', 'top of rock pile'), ('objects', 'small rock'), ('locations', 'on top of object'), ('objects', 'small rock'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')]]
#
# [('locations', 'top of rock pile'), ('objects', 'large rock'), ('objects', 'small rock'), ('locations', 'bottom of rock pile'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('objects', 'small rock')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('locations', 'left side of rock pile'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')]]
#
# [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
#
# [('locations', 'left side of rock pile'), ('objects', 'large rock'), ('locations', 'left side of field'), ('objects', 'small rock')]
# [[('locations', 'left side of rock pile'), ('actions', 'pick up object in location'), ('agents', 'robot'), ('objects', 'large rock')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]]
#
# [('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')]]
#
# [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'small rock')]
# [[('agents', 'robot'), ('objects', 'large rock'), ('actions', 'break object in location')], [('agents', 'human'), ('objects', 'small rock'), ('actions', 'pick up object in location')], [('agents', 'robot'), ('objects', 'large rock'), ('actions', 'break object in location')], [('agents', 'robot'), ('agents', 'human'), ('objects', 'small rock'), ('actions', 'pick up object in location')]]
#
# [('objects', 'small rock'), ('locations', 'top of rock pile')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('counters', 'zero')]]
#
# [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'small rock')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')]]
#
# [('locations', 'left side of rock pile'), ('objects', 'large rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')]]
#
# [('locations', 'bottom of rock pile'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]]
#
# [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('locations', 'left side of rock pile')]]
#
# [('locations', 'left side of rock pile'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('objects', 'small rock')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('locations', 'on top of actor')]]
#
# [('locations', 'left side of rock pile'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('objects', 'large rock')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('counters', 'one')]]
#
# [('locations', 'top of rock pile'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('objects', 'large rock')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('actions', 'pick up object in location')]]
#
# [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'small rock')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('locations', 'top of rock pile'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]]
#
# [('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'bottom of rock pile'), ('objects', 'small rock'), ('locations', 'bottom of rock pile'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('locations', 'bottom of rock pile'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('locations', 'bottom of rock pile'), ('objects', 'large rock')]]
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
#
# [('objects', 'large rock'), ('objects', 'small rock'), ('locations', 'top of rock pile')]
# [[('agents', 'robot'), ('actions', 'break object in location')], [('agents', 'robot'), ('actions', 'pick up object in location')]]
#
# [('objects', 'small rock'), ('locations', 'top of rock pile')]
# [[('agents', 'human'), ('actions', 'pick up object in location')]]
#
# [('counters', 'all'), ('objects', 'large rock'), ('objects', 'small rock'), ('locations', 'top of rock pile')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')]]
#
# [('counters', 'all'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
#
# [('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'left side of field')]]
#
# [('objects', 'large rock'), ('locations', 'on top of object'), ('objects', 'large rock')]
# [[('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'right side of field')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'on top of object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'right side of field')], [('agents', 'robot'), ('actions', 'stand still in location'), ('locations', 'right side of field')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock')]]
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')]]
#
# [('counters', 'one'), ('objects', 'large rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]]
#
# [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'top of rock pile')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('objects', 'large rock'), ('locations', 'top of rock pile')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'above rock pile')], [('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'right side of field')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'small rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'above rock pile')]]
#
# [('counters', 'one'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
#
# [('objects', 'large rock'), ('locations', 'top of rock pile')]
# [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('agents', 'human'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')]]
#
# [('locations', 'top of rock pile'), ('objects', 'small rock'), ('agents', 'human')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('counters', 'all')], [('agents', 'human'), ('actions', 'drop object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'left side of field')]]
#
# [('objects', 'large rock'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('agents', 'human'), ('agents', 'robot')]
# [[('agents', 'human'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('counters', 'all')], [('agents', 'robot'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('counters', 'all')], [('actions', 'drop object in location'), ('agents', 'human'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'drop object in location'), ('locations', 'left side of field'), ('objects', 'large rock')]]
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile'), ('agents', 'human'), ('agents', 'robot')]
# [[('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'left side of rock pile'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('counters', 'all'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('counters', 'all'), ('locations', 'left side of field')]]
#
# [('objects', 'small rock'), ('counters', 'all'), ('locations', 'left side of rock pile'), ('locations', 'bottom of rock pile'), ('agents', 'human'), ('agents', 'robot')]
# [[('agents', 'human'), ('objects', 'small rock'), ('actions', 'pick up object in location'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('objects', 'small rock'), ('actions', 'pick up object in location')], [('agents', 'human'), ('objects', 'small rock'), ('actions', 'drop object in location'), ('locations', 'left side of field')], [('agents', 'robot'), ('objects', 'small rock'), ('actions', 'move back and forth in location')]]
#
# [('objects', 'large rock'), ('objects', 'brown rock'), ('locations', 'left side of rock pile'), ('locations', 'top of rock pile'), ('agents', 'robot')]
# [[('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'right side of field')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')], [('agents', 'human'), ('objects', 'small rock'), ('actions', 'pick up object in location'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('objects', 'small rock'), ('actions', 'drop object in location'), ('locations', 'left side of field')], [('agents', 'human'), ('actions', 'move back and forth in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')]]
#
# [('locations', 'top of rock pile'), ('locations', 'left side of rock pile'), ('objects', 'large rock'), ('agents', 'robot'), ('agents', 'human')]
# [[('agents', 'human'), ('actions', 'move to object'), ('locations', 'above rock pile'), ('locations', 'on top of object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')]]
#
# [('locations', 'left side of rock pile'), ('objects', 'small rock'), ('objects', 'large rock'), ('agents', 'human'), ('agents', 'robot')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'human')], [('agents', 'human'), ('actions', 'move to location'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'human')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'human'), ('actions', 'move to location'), ('locations', 'top of rock pile'), ('agents', 'robot')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('objects', 'small rock'), ('actions', 'drop object in location'), ('locations', 'left side of field')]]
#
# [('objects', 'small rock'), ('objects', 'large rock'), ('agents', 'robot'), ('agents', 'human'), ('agents', 'victim'), ('locations', 'top of rock pile')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'move to location'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('objects', 'large rock'), ('actions', 'move to actor'), ('agents', 'human')]]
#
# [('objects', 'large rock'), ('objects', 'small rock'), ('agents', 'human'), ('agents', 'robot'), ('locations', 'left side of rock pile')]
# [[('agents', 'human'), ('actions', 'move to location'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'move to location'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'stand still in location'), ('objects', 'large rock'), ('locations', 'on top of object'), ('locations', 'left side of rock pile')], [('objects', 'large rock'), ('agents', 'robot'), ('actions', 'break object in location'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'human')], [('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'left side of rock pile'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
#
# [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('agents', 'robot'), ('agents', 'human')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('counters', 'all'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('agents', 'human'), ('actions', 'drop object in location'), ('counters', 'all'), ('objects', 'large rock'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('objects', 'small rock'), ('counters', 'all'), ('locations', 'top of rock pile'), ('actions', 'pick up object in location')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('counters', 'all'), ('locations', 'right side of field')]]
#
# [('objects', 'large rock'), ('agents', 'human'), ('locations', 'bottom of rock pile'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'on top of object'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'human')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('objects', 'small rock'), ('locations', 'left side of rock pile'), ('agents', 'human'), ('agents', 'robot')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')]]
#
# [('objects', 'large rock'), ('agents', 'human'), ('agents', 'robot'), ('locations', 'bottom of rock pile'), ('locations', 'left side of rock pile')]
# [[('objects', 'large rock'), ('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'on top of object'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'human')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')]]
#
# [('locations', 'top of rock pile'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'one'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'move to object'), ('counters', 'all'), ('objects', 'small rock')]]
#
# [('objects', 'small rock'), ('locations', 'top of rock pile')]
# [[('agents', 'human'), ('counters', 'one'), ('objects', 'small rock'), ('actions', 'pick up object in location'), ('locations', 'left side of field')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]]
#
# [('objects', 'large rock'), ('objects', 'small rock'), ('agents', 'robot'), ('agents', 'human'), ('locations', 'above rock pile')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')], [('agents', 'human'), ('agents', 'robot'), ('actions', 'move to object'), ('counters', 'all'), ('locations', 'left side of field')]]
#
# [('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'left side of field')]]
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'right side of field')]]
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('actions', 'move to object'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'small rock'), ('actions', 'drop object in location'), ('locations', 'left side of rock pile')]]
#
# [('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('locations', 'above rock pile'), ('objects', 'large rock')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'above rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'right side of field')]]
#
# [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'on top of object'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'on top of object'), ('agents', 'victim')], [('agents', 'robot'), ('objects', 'large rock'), ('actions', 'pick up object in location')], [('agents', 'robot'), ('actions', 'drop object in location'), ('locations', 'on top of object'), ('agents', 'victim')]]
#
# [('locations', 'left side of rock pile'), ('objects', 'large rock'), ('objects', 'small rock'), ('agents', 'robot'), ('agents', 'human'), ('actions', 'break object in location')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock')], [('agents', 'human'), ('actions', 'drop object in location'), ('locations', 'left side of field'), ('objects', 'small rock')]]
#
# [('counters', 'all'), ('objects', 'small rock'), ('agents', 'human'), ('agents', 'robot'), ('locations', 'left side of field'), ('locations', 'right side of field')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('counters', 'all'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'right side of field')], [('agents', 'robot'), ('actions', 'drop object in location'), ('counters', 'one'), ('objects', 'small rock'), ('locations', 'left side of field')]]
#
# [('objects', 'large rock'), ('locations', 'bottom of rock pile')]
# [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'bottom of rock pile')], [('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')]]
#
# [('objects', 'large rock'), ('objects', 'small rock'), ('agents', 'robot'), ('agents', 'human'), ('locations', 'left side of field'), ('locations', 'right side of field')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')], [('actions', 'drop object in location'), ('agents', 'robot'), ('locations', 'left side of field')], [('agents', 'human'), ('objects', 'small rock'), ('actions', 'pick up object in location')], [('locations', 'left side of field'), ('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'drop object in location'), ('locations', 'right side of field'), ('objects', 'large rock')]]
#
# [('objects', 'large rock'), ('locations', 'bottom of rock pile'), ('agents', 'robot'), ('agents', 'human')]
# [[('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'bottom of rock pile')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')]]
#
# [('locations', 'top of rock pile'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')]]
#
# [('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('actions', 'drop object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('locations', 'top of rock pile'), ('objects', 'small rock')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')]]
#
# [('locations', 'top of rock pile'), ('objects', 'small rock')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')]]
#
# [('agents', 'human'), ('objects', 'small rock')]
# [[('actions', 'move to location'), ('locations', 'left side of rock pile')], [('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]]
#
# [('locations', 'top of rock pile'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')]]
#
# [('agents', 'robot'), ('objects', 'large rock')]
# [[('actions', 'move to location'), ('locations', 'left side of rock pile')], [('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
#
# [('agents', 'robot'), ('objects', 'small rock')]
# [[('actions', 'move to location'), ('locations', 'left side of rock pile')], [('actions', 'drop object in location'), ('counters', 'all'), ('locations', 'left side of rock pile'), ('objects', 'small rock')]]
#
# [('locations', 'bottom of rock pile'), ('objects', 'small rock')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]]
#
# [('locations', 'bottom of rock pile'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'bottom of rock pile')]]
#
# [('locations', 'bottom of rock pile'), ('objects', 'small rock')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]]
#
# [('agents', 'robot'), ('objects', 'large rock')]
# [[('actions', 'move to location'), ('locations', 'right side of rock pile')], [('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of rock pile')]]
#
# [('objects', 'small rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]]
#
# [('objects', 'large rock'), ('locations', 'on top of object'), ('objects', 'small rock')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'bottom of rock pile')]]
#
# [('agents', 'human'), ('objects', 'small rock')]
# [[('actions', 'move to location'), ('locations', 'right side of rock pile')], [('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'right side of rock pile')]]
#
# [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# [[('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'bottom of rock pile')]]
#
# [('agents', 'human'), ('objects', 'small rock')]
# [[('actions', 'move to actor'), ('agents', 'victim')], [('actions', 'drop object in location'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'human')]]
#
# [('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('agents', 'robot'), ('objects', 'small rock')]
# [[('actions', 'move to location'), ('locations', 'right side of rock pile')], [('actions', 'drop object in location'), ('counters', 'all'), ('locations', 'right side of rock pile'), ('objects', 'small rock')]]
#
# [('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'stand still in location'), ('locations', 'on top of location'), ('locations', 'right side of field')]]
#
# [('locations', 'bottom of rock pile'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'bottom of rock pile')]]
#
# [('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'human')]]
#
# [('objects', 'large rock'), ('locations', 'top of rock pile'), ('counters', 'one'), ('objects', 'large rock'), ('locations', 'above rock pile'), ('counters', 'one'), ('agents', 'victim'), ('counters', 'one')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'one'), ('objects', 'small rock')], [('agents', 'human'), ('actions', 'drop object in location'), ('counters', 'one'), ('objects', 'small rock')], [('agents', 'robot'), ('actions', 'break object in location'), ('counters', 'one'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'break object in location'), ('counters', 'one'), ('objects', 'large rock')], [('objects', 'small rock'), ('locations', 'on top of object'), ('agents', 'victim')]]
#
# [('objects', 'small rock'), ('locations', 'top of rock pile')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('counters', 'all')], [('agents', 'robot'), ('actions', 'stand still in location')]]
#
# [('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'human'), ('actions', 'move to location'), ('objects', 'large rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'move to location'), ('objects', 'large rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'break object in location')]]
#
# [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'human')]]
#
# [('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'right side of field')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')]]
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'stand still in location')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
#
# [('objects', 'large rock'), ('locations', 'above rock pile'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'move to location'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'human')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
#
# [('objects', 'large rock'), ('locations', 'on top of object'), ('objects', 'small rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'small rock'), ('locations', 'on top of actor')], [('agents', 'robot'), ('actions', 'move to actor')], [('agents', 'human'), ('actions', 'move to object'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock')]]
#
# [('objects', 'small rock'), ('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'human')]]
#
# [('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'human')], [('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'stand still in location')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')]]
#
# [('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]]
#
# [('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'stand still in location')], [('agents', 'robot'), ('actions', 'move to actor'), ('agents', 'human')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]
# ...
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'robot'), ('locations', 'left side of rock pile'), ('actions', 'break object in location'), ('objects', 'large rock')]]
#
# [('objects', 'large rock'), ('locations', 'top of rock pile')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('counters', 'one')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile'), ('counters', 'one')]]
#
# [('objects', 'small rock'), ('locations', 'top of rock pile')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'bottom of rock pile')]]
#
# [('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')]]
#
# [('objects', 'large rock'), ('locations', 'top of rock pile')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('locations', 'top of rock pile'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'left side of field'), ('locations', 'above rock pile')]]
#
# [('objects', 'small rock'), ('locations', 'top of rock pile')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('counters', 'all')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'right side of field'), ('locations', 'above rock pile'), ('counters', 'all')]]
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'left side of rock pile')]]
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
#
# [('locations', 'top of rock pile'), ('objects', 'large rock')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')]]
#
# [('objects', 'small rock'), ('locations', 'right side of rock pile')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('locations', 'right side of rock pile'), ('objects', 'small rock')], [('agents', 'human'), ('actions', 'move to location'), ('locations', 'left side of field')], [('agents', 'human'), ('actions', 'move to location'), ('locations', 'right side of field')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'right side of field')]]
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field'), ('locations', 'above rock pile')]]
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('objects', 'large rock'), ('locations', 'left side of rock pile'), ('actions', 'pick up object in location')], [('agents', 'robot'), ('actions', 'drop object in location'), ('locations', 'right side of field'), ('locations', 'above rock pile'), ('objects', 'large rock')]]
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('objects', 'large rock'), ('locations', 'left side of rock pile'), ('actions', 'pick up object in location')]]
#
# [('objects', 'large rock'), ('locations', 'top of rock pile'), ('locations', 'on top of object'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'one'), ('objects', 'small rock'), ('locations', 'top of rock pile')]]
#
# [('objects', 'large rock'), ('locations', 'on top of object'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim'), ('objects', 'small rock'), ('locations', 'on top of object'), ('objects', 'large rock')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'stand still in location'), ('locations', 'right side of field')], [('agents', 'victim'), ('actions', 'stand still in location'), ('locations', 'bottom of rock pile')]]
#
# [('counters', 'all'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'on top of actor'), ('agents', 'human')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'stand still in location'), ('locations', 'right side of field')]]
#
# [('counters', 'one'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('counters', 'all'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('locations', 'top of rock pile'), ('locations', 'bottom of rock pile')], [('objects', 'small rock'), ('actions', 'drop object in location'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('counters', 'one'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('objects', 'large rock'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('locations', 'on top of object'), ('objects', 'large rock')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('objects', 'small rock'), ('locations', 'on top of object'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'right side of field')]]
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')]]
#
# [('objects', 'small rock'), ('locations', 'on top of object'), ('agents', 'victim'), ('locations', 'top of rock pile')]
# [[('agents', 'human'), ('actions', 'stand still in location'), ('locations', 'left side of field')]]
#
# [('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('objects', 'small rock'), ('actions', 'drop object in location'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')]]
#
# [('agents', 'human'), ('actions', 'move back and forth in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'above rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]]
#
# [('counters', 'all'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')]]
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'on top of object'), ('objects', 'large rock')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock')]]
#
# [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'move back and forth in location'), ('locations', 'on top of object'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')]]
#
# [('objects', 'small rock'), ('locations', 'top of rock pile'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'robot'), ('actions', 'move back and forth in location'), ('locations', 'on top of actor'), ('agents', 'human')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'break object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('locations', 'left side of rock pile')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'top of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('counters', 'all'), ('objects', 'small rock'), ('locations', 'right side of field')]]
#
# [('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'move to object'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'on top of actor'), ('agents', 'victim')]]
#
# [('objects', 'small rock'), ('objects', 'large rock'), ('locations', 'top of rock pile'), ('locations', 'on top of object'), ('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'left side of field')]]
#
# [('objects', 'small rock'), ('locations', 'left side of rock pile'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')]
# [[('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'left side of rock pile')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')], [('agents', 'human'), ('actions', 'pick up object in location'), ('objects', 'small rock'), ('locations', 'on top of actor'), ('agents', 'victim')], [('agents', 'human'), ('actions', 'drop object in location'), ('objects', 'small rock'), ('locations', 'left side of field')]]
#
# [('objects', 'large rock'), ('locations', 'left side of rock pile')]
# [[('agents', 'human'), ('locations', 'on top of object'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'pick up object in location'), ('objects', 'large rock'), ('locations', 'left side of rock pile')], [('agents', 'robot'), ('actions', 'drop object in location'), ('objects', 'large rock'), ('locations', 'right side of field')]]

# %%
import rdflib

# Create a new RDF graph
g = rdflib.Graph()

# Parse an OWL file
g.parse("foo.owl", format="application/rdf+xml")

# Iterate over each statement in the graph
for stmt in g:
    print(stmt)

# You can also query the graph using SPARQL
query = """
SELECT ?subject ?predicate ?object
WHERE {
  # ?subject ?predicate ?object
}
LIMIT 10
"""

for row in g.query(query):
    print(row)
# Out:
# (rdflib.term.URIRef('http://example.org/myOntology'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Ontology'))
# (rdflib.term.URIRef('http://example.org/myOntology#bottomOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/myOntology#RockPile'))
# (rdflib.term.URIRef('http://example.org/myOntology#above'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/myOntology#rightSideOf'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/myOntology#SmallRock'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/myOntology#Object'))
# (rdflib.term.URIRef('http://example.org/myOntology#moveTo'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/myOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/myOntology#drop'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/myOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/myOntology#Human'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#SmallRock'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#hasState'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/myOntology#BrownRock'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/myOntology#Object'))
# (rdflib.term.URIRef('http://example.org/myOntology#Human'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/myOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/myOntology#bottomOf'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/myOntology#ActorAction'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#pickUp'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/myOntology#drop'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/myOntology#Object'))
# (rdflib.term.URIRef('http://example.org/myOntology#MoveBackAndForth'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/myOntology#ActorAction'))
# (rdflib.term.URIRef('http://example.org/myOntology#BrownRock'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#LargeRock'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/myOntology#Object'))
# (rdflib.term.URIRef('http://example.org/myOntology#Victim'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#break'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/myOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/myOntology#Object'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#StandStill'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#Victim'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/myOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/myOntology#moveTo'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/myOntology#Object'))
# (rdflib.term.URIRef('http://example.org/myOntology#LargeRock'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#Field'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/myOntology#Object'))
# (rdflib.term.URIRef('http://example.org/myOntology#drop'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/myOntology#break'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/myOntology#Object'))
# (rdflib.term.URIRef('http://example.org/myOntology'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#versionInfo'), rdflib.term.Literal('1.0'))
# (rdflib.term.URIRef('http://example.org/myOntology#hasState'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/myOntology#ActorAction'))
# (rdflib.term.URIRef('http://example.org/myOntology#Robot'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#Robot'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/myOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/myOntology#moveTo'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/myOntology#Field'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#Actor'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#break'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/myOntology#StandStill'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/myOntology#ActorAction'))
# (rdflib.term.URIRef('http://example.org/myOntology#RockPile'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/myOntology#Object'))
# (rdflib.term.URIRef('http://example.org/myOntology#topOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/myOntology#RockPile'))
# (rdflib.term.URIRef('http://example.org/myOntology#leftSideOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/myOntology#Object'))
# (rdflib.term.URIRef('http://example.org/myOntology#hasState'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/myOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/myOntology#pickUp'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/myOntology#Object'))
# (rdflib.term.URIRef('http://example.org/myOntology#RockPile'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#pickUp'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/myOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/myOntology#above'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/myOntology#RockPile'))
# (rdflib.term.URIRef('http://example.org/myOntology#rightSideOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/myOntology#Object'))
# (rdflib.term.URIRef('http://example.org/myOntology#leftSideOf'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/myOntology#MoveBackAndForth'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#topOf'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/myOntology'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Ontology'))
# (rdflib.term.URIRef('http://example.org/myOntology#bottomOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://example.org/myOntology#RockPile'))
# (rdflib.term.URIRef('http://example.org/myOntology#above'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/myOntology#rightSideOf'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://example.org/myOntology#SmallRock'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/myOntology#Object'))
# (rdflib.term.URIRef('http://example.org/myOntology#moveTo'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/myOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/myOntology#drop'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://example.org/myOntology#Actor'))
# (rdflib.term.URIRef('http://example.org/myOntology#Human'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#SmallRock'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/myOntology#hasState'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))

# %%
from rdflib import Graph, Namespace, RDF, URIRef
from rdflib.namespace import RDFS, OWL

# Create a new RDF graph
g = Graph()

# Namespace for our ontology
EX = Namespace("http://example.org/myOntology#")

# Bind a prefix to our namespace for more readable output
g.bind("ex", EX)

# Add classes (types) to the graph
robot = URIRef(EX.Robot)
human = URIRef(EX.Human)
large_rock = URIRef(EX.LargeRock)

# Add individuals to the graph
robot1 = URIRef(EX.robot1)
human1 = URIRef(EX.human1)
rock1 = URIRef(EX.rock1)

# Type assertions
g.add((robot1, RDF.type, robot))
g.add((human1, RDF.type, human))
g.add((rock1, RDF.type, large_rock))

# Add relationships
g.add((human1, EX.pickUp, rock1))
g.add((robot1, EX.moveTo, rock1))

# # Serialize the graph in RDF/XML format
# print(g.serialize(format="xml").decode("u8"))

# Or save the graph to a file
# with open("example_graph.rdf", "wb") as f:
#     g.serialize(f, format="xml")
# Out:
# <Graph identifier=Nb31d5d5a95a144cc858005bc4333fe14 (<class 'rdflib.graph.Graph'>)>

# %%
g.serialize("example_graph.rdf", format="xml")
# Out:
# <Graph identifier=N103620075e2641c9a88397147c088478 (<class 'rdflib.graph.Graph'>)>
